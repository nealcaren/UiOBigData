# %% [markdown]
# ## pandas

# %% [markdown]
# This section provides a brief introduction to pandas. The pandas library is a key component for doing data science in Python for a couple of reasons. Most importantly, it provides two data types, series and data frame, that allow you to store and manipulate data in a way that is useful for analysis. Second, it is incredibly useful for importing and exporting data in a wide variety of formats. Finally, it makes descriptive analysis, including both summary statistics and visualizations. This section provides an introduction to the main capabilities of pandas relevant to data analysis.

# %% [markdown]
# Most of the things that you will want to do it Python require importing libraries. convention, pandas is imported as `pd`. Additionally, we enable the ability for pandas graphics to be displayed within the notebook with `%matplotlib inline`.

# %%
import pandas as pd

# %% [markdown]
# ### Reading data

# %% [markdown]
# In the summer of 2017, the Washington Post produced a [report](https://www.washingtonpost.com/graphics/2018/investigations/unsolved-homicide-database/) on murder clearance rates in U.S. cities. The also released the [data](https://github.com/washingtonpost/data-homicides) they collected on Github as a csv file. We can create a new dataframe, called `df`, using the [pandas](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html) `read_csv` method.

# %%
df = pd.read_csv('data/homicide.csv')

# %%
df
# Out:
#               uid  reported_date         victim_last victim_first victim_race  \
# 0      Alb-000001       20100504              GARCIA         JUAN    Hispanic
# 1      Alb-000002       20100216             MONTOYA      CAMERON    Hispanic
# 2      Alb-000003       20100601         SATTERFIELD      VIVIANA       White
# 3      Alb-000004       20100101            MENDIOLA       CARLOS    Hispanic
# 4      Alb-000005       20100102                MULA       VIVIAN       White
# 5      Alb-000006       20100126                BOOK    GERALDINE       White
# 6      Alb-000007       20100127           MALDONADO        DAVID    Hispanic
# 7      Alb-000008       20100127           MALDONADO       CONNIE    Hispanic
# 8      Alb-000009       20100130        MARTIN-LEYVA      GUSTAVO       White
# 9      Alb-000010       20100210             HERRERA       ISRAEL    Hispanic
# 10     Alb-000011       20100212  BARRIUS-CAMPANIONI       HECTOR    Hispanic
# 11     Alb-000012       20100218               LUJAN        KEVIN       White
# 12     Alb-000013       20100222           COLLAMORE         JOHN    Hispanic
# 13     Alb-000014       20100306            CHIQUITO        CORIN       Other
# 14     Alb-000015       20100308              TORRES       HECTOR    Hispanic
# 15     Alb-000016       20100308                GRAY     STEFANIA       White
# 16     Alb-000017       20100322               LEYVA         JOEL    Hispanic
# 17     Alb-000018       20100323               DAVID        LARRY       White
# 18     Alb-000019       20100402               BRITO    ELIZABETH       White
# 19     Alb-000020       20100420              CHAVEZ     GREG SR.    Hispanic
# 20     Alb-000021       20100423                KING       TEVION       Black
# 21     Alb-000022       20100423              BOYKIN       CEDRIC       Black
# 22     Alb-000023       20100518            BARRAGAN       MIGUEL       White
# 23     Alb-000024       20100602                FORD       LUTHER       Other
# 24     Alb-000025       20100602             WRONSKI        VIOLA       White
# 25     Alb-000026       20100603             ASHFORD    GUADALUPE    Hispanic
# 26     Alb-000027       20100712              TURNER     MICHELLE       White
# 27     Alb-000028       20100712          CUNNINGHAM       SHARON       White
# 28     Alb-000029       20100726              NGUYEN     SELENAVI       Asian
# 29     Alb-000030       20100728              VALDEZ         BILL    Hispanic
# ...           ...            ...                 ...          ...         ...
# 52149  Was-001353       20160324              TURNER      GABRIEL       Black
# 52150  Was-001355       20160518             MERIEDY       THOMAS       Black
# 52151  Was-001356       20160906                COOK          JOE       Black
# 52152  Was-001357       20160917            PHILLIPS      SCORPIO       Black
# 52153  Was-001358       20160917              HARRIS       ZORUAN       Black
# 52154  Was-001359       20161108               PRATT       ANTINA       Black
# 52155  Was-001360       20161127              SILVER      ORLANDO       Black
# 52156  Was-001361       20160304              REZENE         NOEL       Black
# 52157  Was-001362       20160511             DRAYTON       JAVION       Black
# 52158  Was-001363       20160702          MCCULLOUGH      ANTOINE       Black
# 52159  Was-001365       20161111                BUIE     SAMUELLE       Black
# 52160  Was-001366       20161111            JENNINGS      RASSAAN       Black
# 52161  Was-001367       20161122               TYLER     MARQUETT       Black
# 52162  Was-001368       20160302              GARRIS      RUDOLPH       Black
# 52163  Was-001369       20160317            DANSBURY       AUBREY       Black
# 52164  Was-001370       20160510               HANEY       JAQUAN       Black
# 52165  Was-001371       20160519            HAMILTON         DANA       Black
# 52166  Was-001372       20160609              WRIGHT      RASHAWN       Black
# 52167  Was-001373       20160626           BLACKWELL      WESTLEY       Black
# 52168  Was-001374       20161227              DOWTIN      HERBERT       Black
# 52169  Was-001375       20160224              MEDLAY    DEMETRIUS       Black
# 52170  Was-001376       20160731            STEPHENS      JUDONNE       Black
# 52171  Was-001377       20160916             PEOPLES      DARNELL       Black
# 52172  Was-001378       20160415                IVEY         PAUL       Black
# 52173  Was-001379       20160715              HARRIS       SHAROD       Black
# 52174  Was-001380       20160908            WILLIAMS         EVAN       Black
# 52175  Was-001381       20160913               SMITH         DEON       Black
# 52176  Was-001382       20161114          WASHINGTON       WILLIE       Black
# 52177  Was-001383       20161130              BARNES       MARCUS       Black
# 52178  Was-001384       20160901             JACKSON        KEVIN       Black
#
#        victim_age victim_sex         city state        lat         lon  \
# 0            78.0       Male  Albuquerque    NM  35.095788 -106.538555
# 1            17.0       Male  Albuquerque    NM  35.056810 -106.715321
# 2            15.0     Female  Albuquerque    NM  35.086092 -106.695568
# 3            32.0       Male  Albuquerque    NM  35.078493 -106.556094
# 4            72.0     Female  Albuquerque    NM  35.130357 -106.580986
# 5            91.0     Female  Albuquerque    NM  35.151110 -106.537797
# 6            52.0       Male  Albuquerque    NM  35.111785 -106.712614
# 7            52.0     Female  Albuquerque    NM  35.111785 -106.712614
# 8            56.0       Male  Albuquerque    NM  35.075380 -106.553458
# 9            43.0       Male  Albuquerque    NM  35.065930 -106.572288
# 10           20.0       Male  Albuquerque    NM  35.077375 -106.560569
# 11            NaN       Male  Albuquerque    NM  35.077011 -106.564910
# 12           46.0       Male  Albuquerque    NM  35.064076 -106.608281
# 13           16.0       Male  Albuquerque    NM  35.041491 -106.742147
# 14           54.0       Male  Albuquerque    NM  35.070656 -106.615845
# 15           43.0     Female  Albuquerque    NM  35.070656 -106.615845
# 16           52.0       Male  Albuquerque    NM  35.079082 -106.495949
# 17           52.0       Male  Albuquerque    NM        NaN         NaN
# 18           22.0     Female  Albuquerque    NM  35.110404 -106.523668
# 19           49.0       Male  Albuquerque    NM  35.089573 -106.570078
# 20           15.0       Male  Albuquerque    NM  35.095887 -106.638081
# 21           25.0       Male  Albuquerque    NM  35.095887 -106.638081
# 22           20.0       Male  Albuquerque    NM  35.083401 -106.632941
# 23           47.0       Male  Albuquerque    NM  35.102423 -106.567674
# 24           88.0     Female  Albuquerque    NM  35.095956 -106.561135
# 25           27.0     Female  Albuquerque    NM  35.078462 -106.551755
# 26           36.0     Female  Albuquerque    NM  35.053748 -106.531800
# 27           47.0     Female  Albuquerque    NM  35.053748 -106.531800
# 28            1.0     Female  Albuquerque    NM  35.064456 -106.524458
# 29           58.0       Male  Albuquerque    NM  35.061827 -106.749104
# ...           ...        ...          ...   ...        ...         ...
# 52149        46.0       Male   Washington    DC  38.857628  -76.996482
# 52150        24.0       Male   Washington    DC  38.862517  -76.990880
# 52151        35.0       Male   Washington    DC  38.854721  -76.990795
# 52152        31.0       Male   Washington    DC  38.877003  -76.995627
# 52153        18.0       Male   Washington    DC  38.877003  -76.995627
# 52154        40.0     Female   Washington    DC  38.855699  -76.993248
# 52155        37.0       Male   Washington    DC  38.860054  -76.991825
# 52156        26.0       Male   Washington    DC  38.849150  -76.971272
# 52157         3.0       Male   Washington    DC  38.853961  -76.984712
# 52158        30.0       Male   Washington    DC  38.843740  -76.977839
# 52159        25.0       Male   Washington    DC  38.851284  -76.981029
# 52160        19.0       Male   Washington    DC  38.851284  -76.981029
# 52161        26.0       Male   Washington    DC  38.849967  -76.974421
# 52162        25.0       Male   Washington    DC  38.827191  -76.998183
# 52163        27.0       Male   Washington    DC  38.829442  -76.993175
# 52164        22.0       Male   Washington    DC  38.833943  -76.990742
# 52165        44.0       Male   Washington    DC  38.828365  -76.994431
# 52166        25.0       Male   Washington    DC  38.835947  -76.990438
# 52167        38.0       Male   Washington    DC  38.834756  -76.992662
# 52168        22.0       Male   Washington    DC  38.833190  -76.994345
# 52169        22.0       Male   Washington    DC  38.843399  -77.000104
# 52170        25.0       Male   Washington    DC  38.863322  -76.995309
# 52171        35.0       Male   Washington    DC  38.845871  -76.998169
# 52172        37.0       Male   Washington    DC  38.826458  -77.003590
# 52173        20.0       Male   Washington    DC  38.827266  -77.001572
# 52174        29.0       Male   Washington    DC  38.828704  -77.002075
# 52175        19.0       Male   Washington    DC  38.822852  -77.001725
# 52176        23.0       Male   Washington    DC  38.828025  -77.002511
# 52177        24.0       Male   Washington    DC  38.820476  -77.008640
# 52178        17.0       Male   Washington    DC  38.866689  -76.982409
#
#                  disposition
# 0      Closed without arrest
# 1           Closed by arrest
# 2      Closed without arrest
# 3           Closed by arrest
# 4      Closed without arrest
# 5             Open/No arrest
# 6           Closed by arrest
# 7           Closed by arrest
# 8             Open/No arrest
# 9             Open/No arrest
# 10          Closed by arrest
# 11     Closed without arrest
# 12            Open/No arrest
# 13          Closed by arrest
# 14          Closed by arrest
# 15          Closed by arrest
# 16          Closed by arrest
# 17          Closed by arrest
# 18          Closed by arrest
# 19          Closed by arrest
# 20          Closed by arrest
# 21          Closed by arrest
# 22          Closed by arrest
# 23          Closed by arrest
# 24     Closed without arrest
# 25          Closed by arrest
# 26     Closed without arrest
# 27     Closed without arrest
# 28     Closed without arrest
# 29            Open/No arrest
# ...                      ...
# 52149       Closed by arrest
# 52150         Open/No arrest
# 52151       Closed by arrest
# 52152         Open/No arrest
# 52153         Open/No arrest
# 52154         Open/No arrest
# 52155       Closed by arrest
# 52156       Closed by arrest
# 52157  Closed without arrest
# 52158       Closed by arrest
# 52159         Open/No arrest
# 52160         Open/No arrest
# 52161         Open/No arrest
# 52162       Closed by arrest
# 52163       Closed by arrest
# 52164         Open/No arrest
# 52165       Closed by arrest
# 52166         Open/No arrest
# 52167         Open/No arrest
# 52168       Closed by arrest
# 52169       Closed by arrest
# 52170         Open/No arrest
# 52171       Closed by arrest
# 52172       Closed by arrest
# 52173         Open/No arrest
# 52174       Closed by arrest
# 52175         Open/No arrest
# 52176         Open/No arrest
# 52177         Open/No arrest
# 52178       Closed by arrest
#
# [52179 rows x 12 columns]

# %% [markdown]
# By default, `read_csv` assumes a comma separator, but this could be customized by adding the  `sep=` parameter. So a pipe-delimited version of the file could be read with:
#
# ~~~python
# df = pd.read_csv('data/homicide.psv', sep='|')
# ~~~
#
# Additionally, read_csv can access file directly from the web.
#
# ```python
# csv_url = 'https://raw.githubusercontent.com/washingtonpost/data-homicides/master/homicide-data.csv'
#
# df = pd.read_csv(csv_url)
# ```
#
# Text files may also include special characters, such as 😎 which can be written as `\U0001f60e`

# %%
print('\U0001f60e')
# Out:
# 😎

# %% [markdown]
# In this case, you might need to set the encoding parameter. With most CSV, files, unfortunately, this is usually a process of trial and error:

# %%
csv_url = 'https://raw.githubusercontent.com/washingtonpost/data-homicides/master/homicide-data.csv'

df = pd.read_csv(csv_url)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~/anaconda3/envs/new_anaconda/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#
# ~/anaconda3/envs/new_anaconda/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#
# ~/anaconda3/envs/new_anaconda/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#
# ~/anaconda3/envs/new_anaconda/lib/python3.7/http/client.py in endheaders(self, message_body, encode_chunked)
#    1223             raise CannotSendHeader()
# -> 1224         self._send_output(message_body, encode_chunked=encode_chunked)
#    1225
#
# ~/anaconda3/envs/new_anaconda/lib/python3.7/http/client.py in _send_output(self, message_body, encode_chunked)
#    1015         del self._buffer[:]
# -> 1016         self.send(msg)
#    1017
#
# ~/anaconda3/envs/new_anaconda/lib/python3.7/http/client.py in send(self, data)
#     955             if self.auto_open:
# --> 956                 self.connect()
#     957             else:
#
# ~/anaconda3/envs/new_anaconda/lib/python3.7/http/client.py in connect(self)
#    1383
# -> 1384             super().connect()
#    1385
#
# ~/anaconda3/envs/new_anaconda/lib/python3.7/http/client.py in connect(self)
#     927         self.sock = self._create_connection(
# --> 928             (self.host,self.port), self.timeout, self.source_address)
#     929         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# ~/anaconda3/envs/new_anaconda/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     706     err = None
# --> 707     for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     708         af, socktype, proto, canonname, sa = res
#
# ~/anaconda3/envs/new_anaconda/lib/python3.7/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     747     addrlist = []
# --> 748     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     749         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# <ipython-input-5-b22410d5c52a> in <module>
#       1 csv_url = 'https://raw.githubusercontent.com/washingtonpost/data-homicides/master/homicide-data.csv'
#       2
# ----> 3 df = pd.read_csv(csv_url)
#
# ~/anaconda3/envs/new_anaconda/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# ~/anaconda3/envs/new_anaconda/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     411     compression = _infer_compression(filepath_or_buffer, compression)
#     412     filepath_or_buffer, _, compression, should_close = get_filepath_or_buffer(
# --> 413         filepath_or_buffer, encoding, compression)
#     414     kwds['compression'] = compression
#     415
#
# ~/anaconda3/envs/new_anaconda/lib/python3.7/site-packages/pandas/io/common.py in get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode)
#     200
#     201     if _is_url(filepath_or_buffer):
# --> 202         req = _urlopen(filepath_or_buffer)
#     203         content_encoding = req.headers.get('Content-Encoding', None)
#     204         if content_encoding == 'gzip':
#
# ~/anaconda3/envs/new_anaconda/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~/anaconda3/envs/new_anaconda/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     523             req = meth(req)
#     524
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# ~/anaconda3/envs/new_anaconda/lib/python3.7/urllib/request.py in _open(self, req, data)
#     541         protocol = req.type
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#     545             return result
#
# ~/anaconda3/envs/new_anaconda/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# ~/anaconda3/envs/new_anaconda/lib/python3.7/urllib/request.py in https_open(self, req)
#    1358         def https_open(self, req):
#    1359             return self.do_open(http.client.HTTPSConnection, req,
# -> 1360                 context=self._context, check_hostname=self._check_hostname)
#    1361
#    1362         https_request = AbstractHTTPHandler.do_request_
#
# ~/anaconda3/envs/new_anaconda/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
# -> 1319                 raise URLError(err)
#    1320             r = h.getresponse()
#    1321         except:
#
# URLError: <urlopen error [Errno 8] nodename nor servname provided, or not known>

# %%
df = pd.read_csv(csv_url, encoding='iso-8859-1')
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~/anaconda3/envs/new_anaconda/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#
# ~/anaconda3/envs/new_anaconda/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#
# ~/anaconda3/envs/new_anaconda/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#
# ~/anaconda3/envs/new_anaconda/lib/python3.7/http/client.py in endheaders(self, message_body, encode_chunked)
#    1223             raise CannotSendHeader()
# -> 1224         self._send_output(message_body, encode_chunked=encode_chunked)
#    1225
#
# ~/anaconda3/envs/new_anaconda/lib/python3.7/http/client.py in _send_output(self, message_body, encode_chunked)
#    1015         del self._buffer[:]
# -> 1016         self.send(msg)
#    1017
#
# ~/anaconda3/envs/new_anaconda/lib/python3.7/http/client.py in send(self, data)
#     955             if self.auto_open:
# --> 956                 self.connect()
#     957             else:
#
# ~/anaconda3/envs/new_anaconda/lib/python3.7/http/client.py in connect(self)
#    1383
# -> 1384             super().connect()
#    1385
#
# ~/anaconda3/envs/new_anaconda/lib/python3.7/http/client.py in connect(self)
#     927         self.sock = self._create_connection(
# --> 928             (self.host,self.port), self.timeout, self.source_address)
#     929         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# ~/anaconda3/envs/new_anaconda/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     706     err = None
# --> 707     for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     708         af, socktype, proto, canonname, sa = res
#
# ~/anaconda3/envs/new_anaconda/lib/python3.7/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     747     addrlist = []
# --> 748     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     749         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# <ipython-input-6-05ea05fcdd30> in <module>
# ----> 1 df = pd.read_csv(csv_url, encoding='iso-8859-1')
#
# ~/anaconda3/envs/new_anaconda/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# ~/anaconda3/envs/new_anaconda/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     411     compression = _infer_compression(filepath_or_buffer, compression)
#     412     filepath_or_buffer, _, compression, should_close = get_filepath_or_buffer(
# --> 413         filepath_or_buffer, encoding, compression)
#     414     kwds['compression'] = compression
#     415
#
# ~/anaconda3/envs/new_anaconda/lib/python3.7/site-packages/pandas/io/common.py in get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode)
#     200
#     201     if _is_url(filepath_or_buffer):
# --> 202         req = _urlopen(filepath_or_buffer)
#     203         content_encoding = req.headers.get('Content-Encoding', None)
#     204         if content_encoding == 'gzip':
#
# ~/anaconda3/envs/new_anaconda/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~/anaconda3/envs/new_anaconda/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     523             req = meth(req)
#     524
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# ~/anaconda3/envs/new_anaconda/lib/python3.7/urllib/request.py in _open(self, req, data)
#     541         protocol = req.type
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#     545             return result
#
# ~/anaconda3/envs/new_anaconda/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# ~/anaconda3/envs/new_anaconda/lib/python3.7/urllib/request.py in https_open(self, req)
#    1358         def https_open(self, req):
#    1359             return self.do_open(http.client.HTTPSConnection, req,
# -> 1360                 context=self._context, check_hostname=self._check_hostname)
#    1361
#    1362         https_request = AbstractHTTPHandler.do_request_
#
# ~/anaconda3/envs/new_anaconda/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
# -> 1319                 raise URLError(err)
#    1320             r = h.getresponse()
#    1321         except:
#
# URLError: <urlopen error [Errno 8] nodename nor servname provided, or not known>

# %% [markdown]
# In this case, the csv file was not encoding in utf-8, but `iso-8859-1`, also know as `latin1`. According to [someone one the intenet](https://w3techs.com/technologies/overview/character_encoding/all), the most frequently used encodings on the web are:
#
# 1. UTF-8 (92% of web pages) - Default for Python 3.x
# 2. ISO-8859-1 (4%) (`encoding = iso-8859-1` or `encoding = latin1`)
# 3. Windows-1251 (1%) - Used for Cyrillic script (`encoding = windows-1251`)
# 4. Windows-1252 (<1%) - Old fork of ISO-8859-1 (`encoding = windows-1252`)
# 3. Shift JIS (<1%) - Japanese characters  (`encoding = shift-jis`)
#
# You might need to Google around for other langauage specific encodings.

# %% [markdown]
# #### Learning about your dataframe
#
# After loading a dataframe, best practice is to get a sense of the data with the `head`, `info` and `describe` methods. `head` shows the first five rows of the dataframe.

# %%
df.head()
# Out:
#           uid  reported_date  victim_last victim_first victim_race victim_age  \
# 0  Alb-000001       20100504       GARCIA         JUAN    Hispanic         78
# 1  Alb-000002       20100216      MONTOYA      CAMERON    Hispanic         17
# 2  Alb-000003       20100601  SATTERFIELD      VIVIANA       White         15
# 3  Alb-000004       20100101     MENDIOLA       CARLOS    Hispanic         32
# 4  Alb-000005       20100102         MULA       VIVIAN       White         72
#
#   victim_sex         city state        lat         lon            disposition
# 0       Male  Albuquerque    NM  35.095788 -106.538555  Closed without arrest
# 1       Male  Albuquerque    NM  35.056810 -106.715321       Closed by arrest
# 2     Female  Albuquerque    NM  35.086092 -106.695568  Closed without arrest
# 3       Male  Albuquerque    NM  35.078493 -106.556094       Closed by arrest
# 4     Female  Albuquerque    NM  35.130357 -106.580986  Closed without arrest

# %% [markdown]
# In addition to the data in the csv file, an index has been created to identifiy each row. By default, this is an interger starting with 0.
#
# If the dataset is wide, middle columns will not be displayed. Also, if text fields are long, only the first few characters will be shown. These can both be adjusted using pandas [display settings](https://pandas.pydata.org/pandas-docs/stable/options.html).

# %% [markdown]
# `info` can be used to explore the data types and the number of non-missing cases for each variable.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52179 entries, 0 to 52178
# Data columns (total 12 columns):
# uid              52179 non-null object
# reported_date    52179 non-null int64
# victim_last      52179 non-null object
# victim_first     52179 non-null object
# victim_race      52179 non-null object
# victim_age       52179 non-null object
# victim_sex       52179 non-null object
# city             52179 non-null object
# state            52179 non-null object
# lat              52119 non-null float64
# lon              52119 non-null float64
# disposition      52179 non-null object
# dtypes: float64(2), int64(1), object(9)
# memory usage: 4.8+ MB

# %% [markdown]
# `describe` provides summary statistics for all the numeric variables.

# %%
df.describe()
# Out:
#        reported_date    victim_age           lat           lon  \
# count   5.217900e+04  49180.000000  52119.000000  52119.000000
# mean    2.013090e+07     31.801220     37.026786    -91.471094
# std     1.123420e+06     14.418692      4.348647     13.746378
# min     2.007010e+07      0.000000     25.725214   -122.507779
# 25%     2.010032e+07     22.000000     33.765203    -95.997198
# 50%     2.012122e+07     28.000000     38.524973    -87.710286
# 75%     2.015091e+07     40.000000     40.027627    -81.755909
# max     2.015111e+08    102.000000     45.051190    -71.011519
#
#        victim_age_numeric
# count        49180.000000
# mean            31.801220
# std             14.418692
# min              0.000000
# 25%             22.000000
# 50%             28.000000
# 75%             40.000000
# max            102.000000

# %% [markdown]
# The column headers can be extracted using `keys`.

# %%
df.keys()
# Out:
# Index(['uid', 'reported_date', 'victim_last', 'victim_first', 'victim_race',
#        'victim_age', 'victim_sex', 'city', 'state', 'lat', 'lon',
#        'disposition', 'victim_age_numeric'],
#       dtype='object')

# %% [markdown]
# If you wanted to look at the bottom of the dataframe, you can use `tail`. Both `head` and `tail` allow you to change the number of rows displayed from the default five.

# %%
df.tail(3)
# Out:
#               uid  reported_date victim_last victim_first victim_race  \
# 52176  Was-001382       20161114  WASHINGTON       WILLIE       Black
# 52177  Was-001383       20161130      BARNES       MARCUS       Black
# 52178  Was-001384       20160901     JACKSON        KEVIN       Black
#
#        victim_age victim_sex        city state        lat        lon  \
# 52176        23.0       Male  Washington    DC  38.828025 -77.002511
# 52177        24.0       Male  Washington    DC  38.820476 -77.008640
# 52178        17.0       Male  Washington    DC  38.866689 -76.982409
#
#             disposition  victim_age_numeric
# 52176    Open/No arrest                23.0
# 52177    Open/No arrest                24.0
# 52178  Closed by arrest                17.0

# %% [markdown]
# `sample` displays random rows from the dataframe.

# %%
df.sample(5)
# Out:
#               uid  reported_date victim_last  victim_first victim_race  \
# 34260  Mil-000542       20131220       EVANS      REGINALD       Black
# 35978   NO-000017       20100112     Unknown       Unknown       Black
# 17171  Det-000757       20161012       HATEN      QUASSHIE       Black
# 33338  Mia-000394       20120806      CRESPO  RAFAEL ANGEL    Hispanic
# 33411  Mia-000469       20130902   HYPPOLITE     DEMETRIUS       Black
#
#        victim_age victim_sex         city state        lat        lon  \
# 34260        21.0       Male    Milwaukee    wI  43.071811 -87.888169
# 35978        15.0       Male  New Orleans    LA  30.033230 -90.019913
# 17171        23.0       Male      Detroit    MI  42.375000 -83.095565
# 33338        59.0       Male        Miami    FL  25.786997 -80.222974
# 33411        26.0       Male        Miami    FL  25.791375 -80.198676
#
#                  disposition
# 34260       Closed by arrest
# 35978         Open/No arrest
# 17171       Closed by arrest
# 33338         Open/No arrest
# 33411  Closed without arrest

# %% [markdown]
# <div class="alert alert-info">
# <h3> Your turn</h3>
# <p> Display the first four rows of the dataframe <code>df</code>.
# </div>

# %%
df[-3:]
# Out:
#               uid  reported_date victim_last victim_first victim_race  \
# 52176  Was-001382       20161114  WASHINGTON       WILLIE       Black
# 52177  Was-001383       20161130      BARNES       MARCUS       Black
# 52178  Was-001384       20160901     JACKSON        KEVIN       Black
#
#        victim_age victim_sex        city state        lat        lon  \
# 52176        23.0       Male  Washington    DC  38.828025 -77.002511
# 52177        24.0       Male  Washington    DC  38.820476 -77.008640
# 52178        17.0       Male  Washington    DC  38.866689 -76.982409
#
#             disposition  victim_age_numeric
# 52176    Open/No arrest                23.0
# 52177    Open/No arrest                24.0
# 52178  Closed by arrest                17.0

# %% [markdown]
# ### Working with variables

# %%
df.head(2)
# Out:
#           uid  reported_date victim_last victim_first victim_race  victim_age  \
# 0  Alb-000001       20100504      GARCIA         JUAN    Hispanic        78.0
# 1  Alb-000002       20100216     MONTOYA      CAMERON    Hispanic        17.0
#
#   victim_sex         city state        lat         lon            disposition  \
# 0       Male  Albuquerque    NM  35.095788 -106.538555  Closed without arrest
# 1       Male  Albuquerque    NM  35.056810 -106.715321       Closed by arrest
#
#    victim_age_numeric
# 0                78.0
# 1                17.0

# %%
df['victim_age'].describe()
# Out:
# count    49180.000000
# mean        31.801220
# std         14.418692
# min          0.000000
# 25%         22.000000
# 50%         28.000000
# 75%         40.000000
# max        102.000000
# Name: victim_age, dtype: float64

# %%
df['victim_age'].value_counts()
# Out:
# 22.0     2116
# 21.0     2097
# 23.0     2061
# 24.0     1995
# 19.0     1976
# 20.0     1919
# 25.0     1906
# 26.0     1778
# 18.0     1644
# 27.0     1582
# 29.0     1554
# 28.0     1553
# 30.0     1432
# 32.0     1224
# 31.0     1218
# 33.0     1124
# 34.0     1112
# 17.0     1107
# 35.0     1047
# 36.0      934
# 37.0      869
# 38.0      838
# 39.0      762
# 40.0      744
# 16.0      715
# 41.0      688
# 43.0      675
# 42.0      659
# 44.0      613
# 45.0      606
#          ...
# 6.0        46
# 12.0       44
# 79.0       44
# 7.0        43
# 77.0       42
# 10.0       41
# 83.0       38
# 11.0       37
# 8.0        34
# 84.0       31
# 81.0       29
# 9.0        29
# 85.0       26
# 80.0       26
# 82.0       26
# 86.0       25
# 88.0       21
# 89.0       18
# 90.0       13
# 87.0       13
# 91.0       11
# 93.0        7
# 92.0        6
# 94.0        5
# 95.0        5
# 97.0        3
# 96.0        2
# 99.0        1
# 101.0       1
# 102.0       1
# Name: victim_age, Length: 101, dtype: int64

# %% [markdown]
# As this has many values, pandas only displays the top and bottom 30 cases. The `values` method can be used to produce an array containing all the values in order.

# %% [markdown]
# <div class="alert alert-info">
# <h3> Your turn</h3>
# <p> Explore the <code>disposition</code> and <code>victim race</code>   columns in the dataframe.
# </div>

# %% [markdown]
# All of the values of a specific variables can be extracted.

# %%
ages = df['victim_age'].values
len(ages)
# Out:
# 52179

# %%
first_age = age_values[0]
print(first_age)
# Out:
# 78

# %% [markdown]
# <div class="alert alert-info">
# <h3> Your turn</h3>
# <p> Display seven value from the middle of our age variable?
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h3> Your turn</h3>
# <p> A well-known data set is the list of titanic passengers. A version can be found in the data folder called, "titanic.csv". Open the file as a new dataframe <code>titanic_df</code>. How many cases? How many columns? What can you find out about the data?
#
# </div>

# %% [markdown]
# #### Plots
#
# pandas also has plotting capabilies, such as histograms (`hist`) and a correlation matrix (`scatter_matrix`).

# %%
# %matplotlib inline

# %%
df['victim_age_numeric'].hist()

# %% [markdown]
# Plot of individual variables, or series in pandas terminology, are attributes of the data type. That is, you start wit the thing you want plotted, in this case `df['victim_age_numeric']`, and append what you want to do, such as `.hist()`.
#
# A second type of plots, such as scatter plots, are methods of the dataframe.

# %%
df.plot.scatter(x='lon', y='lat')

# %% [markdown]
# You could look at the other dataframe plotting methods on the helpful [pandas visualizations page](https://pandas.pydata.org/pandas-docs/stable/visualization.html). Alternatively, typing tab after `df.plot.` also reveals your options.
#
# <img src="images/auto.png"  width="150px" align="left" /><p>

# %% [markdown]
# Want to know about `hexbin`? Again, the help page on the web is useful, but appending a question mark to the end of the command will bring up the documentation.
#
#
# ```df.plot.hexbin?```
#
# <img src="images/docstring.png" width = "80%" align="left"/>

# %% [markdown]
# A third group of plots are part of the pandas plotting library. In these cases, the thing you want plotted is the first, or only, parameter passed, as is the case with the correlation matrix.

# %%
pd.plotting.scatter_matrix(df)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x126edbb38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x126f5fc50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x123e0e208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x123e3f7b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x123e71d68>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x123eae358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1263b8908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1263eeef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1263eef28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12645ba58>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12649a048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1264c95f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1264fbba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12653b198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12656a748>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12659fcf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1265da2e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12660b898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x126640e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12667b438>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1266af9e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1266e2f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12671d588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x126750b38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12678d128>]],
#       dtype=object)

# %% [markdown]
# Finally, you can also create subplots using the `by` option. Note that `by` accepts a series, or dataframe column, rather than a column name.

# %%
df['victim_age'].hist(by   = df['victim_sex'], 
                              bins = 20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x127800b38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1261ca3c8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1284dd390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x128531940>]],
#       dtype=object)

# %% [markdown]
# By default, `by` produces separate x and y scales for each subgraph. This is why it appears to be a relatively large number of deaths of very young females. The numbers between men and women at this age are comparable, but the very large number of male deaths in their 20s results in very different xscales for the graphs. This option can be changed with the `sharex` or `sharey` option.

# %%
df['victim_age'].hist(by     = df['victim_sex'], 
                              bins   = 20,
                              sharex = True,
                              sharey = True)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x112254128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12873d4e0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x128816780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x128626a20>]],
#       dtype=object)

# %% [markdown]
# #### Other descriptives
#
# Pandas also has a method for producing crosstabs.

# %%
pd.crosstab(df['victim_race'], df['disposition'])
# Out:
# disposition  Closed by arrest  Closed without arrest  Open/No arrest
# victim_race
# Asian                     410                     72             203
# Black                   15462                   1496           16403
# Hispanic                 3332                    401            3168
# Other                     366                     30             304
# Unknown                  2145                    320            1734
# White                    3959                    603            1771

# %% [markdown]
# Note that since this is a pandas method, and not one of a specific dataframe, you need to be explicit about which datatframe each variable is coming from. That is why the first parameter is not `'victim_race'` but `df['victim_race']`.

# %% [markdown]
# `normalize` can be used to display percentages instead of frequencies. A value of `index` normalized by row, `columns` by column, and `all` by all values.

# %%
pd.crosstab(df['victim_race'], df['disposition'], normalize='index')
# Out:
# disposition  Closed by arrest  Closed without arrest  Open/No arrest
# victim_race
# Asian                0.598540               0.105109        0.296350
# Black                0.463475               0.044843        0.491682
# Hispanic             0.482829               0.058108        0.459064
# Other                0.522857               0.042857        0.434286
# Unknown              0.510836               0.076209        0.412955
# White                0.625138               0.095216        0.279646

# %% [markdown]
# Since this returns a dataframe, it can be saved or plotted.

# %%
cross_tab = pd.crosstab(df['victim_race'], df['disposition'], normalize='index')

cross_tab
# Out:
# disposition  Closed by arrest  Closed without arrest  Open/No arrest
# victim_race
# Asian                0.598540               0.105109        0.296350
# Black                0.463475               0.044843        0.491682
# Hispanic             0.482829               0.058108        0.459064
# Other                0.522857               0.042857        0.434286
# Unknown              0.510836               0.076209        0.412955
# White                0.625138               0.095216        0.279646

# %%
cross_tab.to_csv('data/crosstab.csv')

# %% [markdown]
# <div class="alert alert-info">
# <h3> Your turn</h3>
# <p> In your titanic dataframe, run a crosstab between sex and survived. Anything interesting?
#
# </div>

# %% [markdown]
# In order to highlight a meaningful characteristics of the data, you can sort before plotting.

# %%
cross_tab.sort_values(by='Closed by arrest')
# Out:
# disposition  Closed by arrest  Closed without arrest  Open/No arrest
# victim_race
# Black                0.463475               0.044843        0.491682
# Hispanic             0.482829               0.058108        0.459064
# Unknown              0.510836               0.076209        0.412955
# Other                0.522857               0.042857        0.434286
# Asian                0.598540               0.105109        0.296350
# White                0.625138               0.095216        0.279646

# %%
cross_tab.sort_values(by='Closed by arrest').plot(kind   = 'barh',
                                                  title  = 'Disposition by race')

# %% [markdown]
# #### Subsets
#
# Similar to a list, a dataframe or series can be sliced to subset the data being shown. For example, `df[:2]` will return the first two rows of the dataframe. (This is identical to `df.head(2)`.)

# %%
df[:2]
# Out:
#           uid  reported_date victim_last victim_first victim_race  victim_age  \
# 0  Alb-000001       20100504      GARCIA         JUAN    Hispanic        78.0
# 1  Alb-000002       20100216     MONTOYA      CAMERON    Hispanic        17.0
#
#   victim_sex         city state        lat         lon            disposition  \
# 0       Male  Albuquerque    NM  35.095788 -106.538555  Closed without arrest
# 1       Male  Albuquerque    NM  35.056810 -106.715321       Closed by arrest
#
#    victim_age_numeric
# 0                78.0
# 1                17.0

# %%
df.head(2)
# Out:
#           uid  reported_date victim_last victim_first victim_race  victim_age  \
# 0  Alb-000001       20100504      GARCIA         JUAN    Hispanic        78.0
# 1  Alb-000002       20100216     MONTOYA      CAMERON    Hispanic        17.0
#
#   victim_sex         city state        lat         lon            disposition  \
# 0       Male  Albuquerque    NM  35.095788 -106.538555  Closed without arrest
# 1       Male  Albuquerque    NM  35.056810 -106.715321       Closed by arrest
#
#    victim_age_numeric
# 0                78.0
# 1                17.0

# %% [markdown]
# This also works for specific columns.

# %%
df['reported_date'][:3]
# Out:
# 0    20100504
# 1    20100216
# 2    20100601
# Name: reported_date, dtype: int64

# %% [markdown]
# #### Dates
#
# A new variable can be created from `reported_date` that pandas understands is a date variable using the `to_datetime` method. The format is `%Y%m%d` because the original date is in the "YYYMMDD" format, and `coerce` places missing values where the data can be translated, rather than stopping the variable creation completely.

# %%
df['reported_date'].head()
# Out:
# 0    20100504
# 1    20100216
# 2    20100601
# 3    20100101
# 4    20100102
# Name: reported_date, dtype: int64

# %%
df['date'] = pd.to_datetime(df['reported_date'], 
                            format='%Y%m%d', 
                            errors='coerce')

# %%
df['date'][:3]
# Out:
# 0   2010-05-04
# 1   2010-02-16
# 2   2010-06-01
# Name: date, dtype: datetime64[ns]

# %% [markdown]
# From the new series, we can extract specific elements, such as the year.

# %%
df['year'] = df['date'].dt.year

# %% [markdown]
# As before, `value_counts` and plots can give some sense of the distribution of the values.

# %%
df['year'].value_counts()
# Out:
# 2016.0    6290
# 2015.0    5334
# 2017.0    5048
# 2012.0    4908
# 2010.0    4610
# 2014.0    4608
# 2013.0    4599
# 2011.0    4562
# 2007.0    4268
# 2008.0    4215
# 2009.0    3735
# Name: year, dtype: int64

# %% [markdown]
# Value counts returns a pandas series with an index equal to the original values, in the case the year, and the series values based on the frequency. Since years have an order, it makes sense to sort by the index before plotting them.

# %%
df['year'].value_counts().sort_index(ascending = False).plot(kind='barh')

# %% [markdown]
# `crosstab` can also group based on more than one variable for the x or y axis. In that case, you pass a list rather than a single variable or series. To make this clearer, you can create the lists before creating the crosstab.

# %%
y_vars = [df['state'], df['city']]
x_vars = df['year']

pd.crosstab(y_vars, x_vars)
# Out:
# year                  2007.0  2008.0  2009.0  2010.0  2011.0  2012.0  2013.0  \
# state city
# AL    Birmingham          92      81      65      58      54      68      64
#       Tulsa                0       0       0       0       0       0       0
# AZ    Phoenix              0       0       0       0     124     126     124
# CA    Fresno              52      40      42      45      35      51      39
#       Long Beach          39      41      42      33      28      34      37
#       Los Angeles          0       0       0     295     298     298     250
#       Oakland              0     119     103      91     101     126      89
#       Sacramento          44      49      31      34      36      34      34
#       San Bernardino       0       0       0       0       0      43      44
#       San Diego           60      53      41      29      38      48      39
#       San Francisco       99      96      45      49      52      69      46
#       Stockton            30      23      34      50      58      71      32
# CO    Denver               0       0       0      38      43      40      42
# DC    Washington         181     186     144     132     108      88     104
# FL    Jacksonville       131     120      99      90      75     100     103
#       Miami               79      64      60      69      71      54      69
#       Tampa                0       0       0      28       0      23      27
# GA    Atlanta            127     105      80      93      88      83      83
#       Savannah            17      22      20      15      25      18      21
# IL    Chicago            445     510     457     434     437     505     423
# IN    Indianapolis       113     114      99      92      96      96     125
# KY    Louisville           0       0       0      52      53      62      48
# LA    Baton Rouge          0       0       0       0      64      67      49
#       New Orleans          0       2       2     186     211     206     157
# MA    Boston              66      66      49      74      64      59      42
# MD    Baltimore          280     234     236     220     197     216     231
# MI    Detroit              0       0       0     310     346     386     337
# MN    Minneapolis         41      35      15      35      35      42      41
# MO    Kansas City         87     119     103     101     111     105     100
#       St. Louis          140     167     146     142     113     112     121
# NC    Charlotte           72      83      55      61      56      51      54
#       Durham              26      24      22      23      27      21      28
# NE    Omaha               41      44      33      33      39      39      40
# NM    Albuquerque          0       0       0      45      38      46      33
# NV    Las Vegas          119     133     121     112      88      81      97
# NY    Buffalo             56      37      61      54      36      50      47
#       New York             0       0       0       0       0       0       0
# OH    Cincinnati          67      76      56      70      66      53      75
#       Columbus            79     108      84     105      90      90      93
# OK    Oklahoma City       67      56      58      48      59      82      62
#       Tulsa               67      56      67      60      54      42      63
# PA    Philadelphia       389     332     304     304     322     333     249
#       Pittsburgh          64      79      44      61      46      43      46
# TN    Memphis            133     137     132      92     116     134     127
#       Nashville           77      74      80      56      55      63      40
# TX    Dallas             194     168     164     147     135     151     139
#       Fort Worth          58      48      44      64      50      45      56
#       Houston            350     293     286     268     198     217     214
#       San Antonio        127     119     100      76       0       0      77
# VA    Richmond            56      31      39      41      37      44      37
# wI    Milwaukee          103      71      72      95      89      93     101
#
# year                  2014.0  2015.0  2016.0  2017.0
# state city
# AL    Birmingham          52      78      90      98
#       Tulsa                0       0       1       0
# AZ    Phoenix            117     116     146     161
# CA    Fresno              49      39      39      56
#       Long Beach          26      40      37      21
#       Los Angeles        260     282     293     281
#       Oakland             78      83      85      72
#       Sacramento          27      45      40       2
#       San Bernardino      45      44      62      37
#       San Diego           31      38      50      34
#       San Francisco       44      51      57      55
#       Stockton            49      48      49       0
# CO    Denver              31      53      57       8
# DC    Washington         105     162     135       0
# FL    Jacksonville       101     103     114     132
#       Miami               82      75      59      60
#       Tampa               28      34      29      39
# GA    Atlanta             93      95     111      15
#       Savannah            25      42      37       4
# IL    Chicago            418     487     765     654
# IN    Indianapolis       138     144     150     155
# KY    Louisville          58      81     117     105
# LA    Baton Rouge         52      61      44      87
#       New Orleans        163     168     176     163
# MA    Boston              55      39      46      54
# MD    Baltimore          211     342     320     340
# MI    Detroit            294     280     300     266
# MN    Minneapolis         33      48      34       7
# MO    Kansas City         81     112     121     150
#       St. Louis          160     186     188     202
# NC    Charlotte           42      60      68      85
#       Durham              24      37      40       4
# NE    Omaha               32      50      29      29
# NM    Albuquerque         28      50      63      75
# NV    Las Vegas          124     131     158     217
# NY    Buffalo             63      41      45      31
#       New York             0       0     335     292
# OH    Cincinnati          62      36      62      71
#       Columbus            91     100     104     140
# OK    Oklahoma City       43      73      71      53
#       Tulsa               50      54      69       1
# PA    Philadelphia       249     277     277       1
#       Pittsburgh          71      60      59      58
# TN    Memphis            136     134     194     179
#       Nashville           44      82      85     111
# TX    Dallas             121     131     172      45
#       Fort Worth          53      57      65       9
#       Houston            241     303     302     270
#       San Antonio         99      94     141       0
# VA    Richmond            42      42      60       0
# wI    Milwaukee           87     146     139     119

# %% [markdown]
# Crosstab returns a dataframe with the column and index names from the values in the original dataset. Since a list was passed, the datatframe has a `MultiIndex`. The can be useful for cases where you have nested data, like cities with states or annual data on multiple countries.

# %%
pd.crosstab(y_vars, x_vars).index.names
# Out:
# FrozenList(['state', 'city'])

# %% [markdown]
# ### Index

# %%
df.head()
# Out:
#           uid  reported_date  victim_last victim_first victim_race  \
# 0  Alb-000001       20100504       GARCIA         JUAN    Hispanic
# 1  Alb-000002       20100216      MONTOYA      CAMERON    Hispanic
# 2  Alb-000003       20100601  SATTERFIELD      VIVIANA       White
# 3  Alb-000004       20100101     MENDIOLA       CARLOS    Hispanic
# 4  Alb-000005       20100102         MULA       VIVIAN       White
#
#    victim_age victim_sex         city state        lat         lon  \
# 0        78.0       Male  Albuquerque    NM  35.095788 -106.538555
# 1        17.0       Male  Albuquerque    NM  35.056810 -106.715321
# 2        15.0     Female  Albuquerque    NM  35.086092 -106.695568
# 3        32.0       Male  Albuquerque    NM  35.078493 -106.556094
# 4        72.0     Female  Albuquerque    NM  35.130357 -106.580986
#
#              disposition  victim_age_numeric       date    year
# 0  Closed without arrest                78.0 2010-05-04  2010.0
# 1       Closed by arrest                17.0 2010-02-16  2010.0
# 2  Closed without arrest                15.0 2010-06-01  2010.0
# 3       Closed by arrest                32.0 2010-01-01  2010.0
# 4  Closed without arrest                72.0 2010-01-02  2010.0

# %% [markdown]
# By default, the index is a series that starts with 0. If your data has unique identifiers, however, it is helpful to use that as the index, especially if you intend on merging your data with other data sources. In this dataframe, each row has a unique value for `uid`.

# %%
df.set_index('uid', inplace=True)

# %%
df[:5]
# Out:
#             reported_date  victim_last victim_first victim_race  victim_age  \
# uid
# Alb-000001       20100504       GARCIA         JUAN    Hispanic        78.0
# Alb-000002       20100216      MONTOYA      CAMERON    Hispanic        17.0
# Alb-000003       20100601  SATTERFIELD      VIVIANA       White        15.0
# Alb-000004       20100101     MENDIOLA       CARLOS    Hispanic        32.0
# Alb-000005       20100102         MULA       VIVIAN       White        72.0
#
#            victim_sex         city state        lat         lon  \
# uid
# Alb-000001       Male  Albuquerque    NM  35.095788 -106.538555
# Alb-000002       Male  Albuquerque    NM  35.056810 -106.715321
# Alb-000003     Female  Albuquerque    NM  35.086092 -106.695568
# Alb-000004       Male  Albuquerque    NM  35.078493 -106.556094
# Alb-000005     Female  Albuquerque    NM  35.130357 -106.580986
#
#                       disposition  victim_age_numeric       date    year
# uid
# Alb-000001  Closed without arrest                78.0 2010-05-04  2010.0
# Alb-000002       Closed by arrest                17.0 2010-02-16  2010.0
# Alb-000003  Closed without arrest                15.0 2010-06-01  2010.0
# Alb-000004       Closed by arrest                32.0 2010-01-01  2010.0
# Alb-000005  Closed without arrest                72.0 2010-01-02  2010.0

# %% [markdown]
# <div class="alert alert-info">
# <h3> Your turn</h3>
# <p> In your Titanic dataframe, set the index to the <code>PassengerId</code> column. Confirm that it did want you wanted it to do.
#
# </div>

# %% [markdown]
# #### Subseting
#
# You can view a subset of a dataframe based on the value of a column.
#
# Let's say that you wanted to look at the cases where the victim's first name was "Juan". You could create a new series which is either `True` or `False` for each case.

# %%
df['victim_first'] == 'JUAN'
# Out:
# uid
# Alb-000001     True
# Alb-000002    False
# Alb-000003    False
# Alb-000004    False
# Alb-000005    False
# Alb-000006    False
# Alb-000007    False
# Alb-000008    False
# Alb-000009    False
# Alb-000010    False
# Alb-000011    False
# Alb-000012    False
# Alb-000013    False
# Alb-000014    False
# Alb-000015    False
# Alb-000016    False
# Alb-000017    False
# Alb-000018    False
# Alb-000019    False
# Alb-000020    False
# Alb-000021    False
# Alb-000022    False
# Alb-000023    False
# Alb-000024    False
# Alb-000025    False
# Alb-000026    False
# Alb-000027    False
# Alb-000028    False
# Alb-000029    False
# Alb-000030    False
#               ...
# Was-001353    False
# Was-001355    False
# Was-001356    False
# Was-001357    False
# Was-001358    False
# Was-001359    False
# Was-001360    False
# Was-001361    False
# Was-001362    False
# Was-001363    False
# Was-001365    False
# Was-001366    False
# Was-001367    False
# Was-001368    False
# Was-001369    False
# Was-001370    False
# Was-001371    False
# Was-001372    False
# Was-001373    False
# Was-001374    False
# Was-001375    False
# Was-001376    False
# Was-001377    False
# Was-001378    False
# Was-001379    False
# Was-001380    False
# Was-001381    False
# Was-001382    False
# Was-001383    False
# Was-001384    False
# Name: victim_first, Length: 52179, dtype: bool

# %% [markdown]
# You could store this new true/false series. If you placed this in brackets after the name of the dataframe, pandas would display only the rows with a True value.

# %%
is_juan = df['victim_first'] == 'JUAN'
df[is_juan]
# Out:
#             reported_date       victim_last victim_first victim_race  \
# uid
# Alb-000001       20100504            GARCIA         JUAN    Hispanic
# Alb-000315       20170207            ROMERO         JUAN       White
# Bal-002139       20090125           JOHNSON         JUAN       Black
# Bat-000099       20120701             LOPEZ         JUAN    Hispanic
# Bat-000219       20141116            JOSEPH         JUAN       Black
# Bat-000329       20161211        MONTGOMERY         JUAN       Black
# Bir-000676       20080406            CARTER         JUAN       Black
# Bos-000131       20140930             NUNEZ         JUAN    Hispanic
# Buf-000283       20090318          QUINONES         JUAN    Hispanic
# Buf-000604       20150901    ORTIZ-SANTIAGO         JUAN    Hispanic
# Cha-000317       20081206          MARTINEZ         JUAN    Hispanic
# Cha-000403       20100509         CONTRERAS         JUAN    Hispanic
# Chi-003487       20070701            OROZCO         JUAN    Hispanic
# Chi-003521       20070723             REYES         JUAN    Hispanic
# Chi-003556       20070818             RAMOS         JUAN    Hispanic
# Chi-003742       20080108            LEBRON         JUAN    Hispanic
# Chi-003931       20080617         HERNANDEZ         JUAN    Hispanic
# Chi-003937       20080620            TORRES         JUAN    Hispanic
# Chi-003976       20080712          AGUILERA         JUAN    Hispanic
# Chi-004165       20081026             URIBE         JUAN    Hispanic
# Chi-004275       20090217           BONILLA         JUAN    Hispanic
# Chi-004301       20090319            TORRES         JUAN    Hispanic
# Chi-004337       20090423         HERNANDEZ         JUAN    Hispanic
# Chi-004810       20100423            MENDEZ         JUAN    Hispanic
# Chi-005053       20101011          MARTINEZ         JUAN    Hispanic
# Chi-005079       20101106          GONZALEZ         JUAN    Hispanic
# Chi-005316       20110630          BAUTISTA         JUAN    Hispanic
# Chi-005509       20111106           SANCHEZ         JUAN    Hispanic
# Chi-005581       20120108          MELENDEZ         JUAN    Hispanic
# Chi-006810       20141012           MERCADO         JUAN    Hispanic
# ...                   ...               ...          ...         ...
# Pho-000721       20160917   GONZALEZ-GARCIA         JUAN     Unknown
# SA-000054        20080705          CARVAJAL         JUAN    Hispanic
# SA-000063        20071117           CABRERA         JUAN    Hispanic
# SA-000074        20080901          HINOJOSA         JUAN    Hispanic
# SA-000092        20081009         MALDONADO         JUAN    Hispanic
# SA-000112        20081204           ALVAREZ         JUAN    Hispanic
# SA-000151        20070407             PARDO         JUAN       Other
# SA-000202        20070823             ABITU         JUAN       Other
# SA-000206        20070830          SALDIVAR         JUAN       Other
# SA-000328        20091018           SANTANA         JUAN       Other
# SA-000395        20100802             DURAN         JUAN    Hispanic
# SA-000653        20130826            FRAIRE         JUAN    Hispanic
# SA-000712        20140513  SANDOVAL-RAMIREZ         JUAN    Hispanic
# SA-000834        20150625             TREJO         JUAN    Hispanic
# SA-000868        20151018          CASTILLO         JUAN    Hispanic
# SA-000943        20160619             AMARO         JUAN    Hispanic
# SB-000093        20151202          ESPINOZA         JUAN       Other
# SD-000429        20170107             YOUNG         JUAN       Black
# SF-000066        20070804         MALDONADO         JUAN    Hispanic
# SF-000072        20070831           SANCHEZ         JUAN    Hispanic
# SF-000142        20080531         RODRIGUEZ         JUAN    Hispanic
# SF-000257        20100418  MENDEZ-HERNANDEZ         JUAN    Hispanic
# StL-001150       20090819            CANNON         JUAN       Black
# Tam-000113       20140225           ORDONEZ         JUAN    Hispanic
# Tul-000205       20070610             DAVIS         JUAN       Black
# Tul-000247       20080322         RODRIGUEZ         JUAN    Hispanic
# Tul-000253       20080509          CASTILLO         JUAN       White
# Tul-000605       20140211           MENDOZA         JUAN       White
# Tul-000741       20160529       GARCIALICEA         JUAN    Hispanic
# Was-000392       20120118           PAREDES         JUAN    Hispanic
#
#             victim_age victim_sex            city state        lat  \
# uid
# Alb-000001        78.0       Male     Albuquerque    NM  35.095788
# Alb-000315        26.0       Male     Albuquerque    NM  35.080584
# Bal-002139        14.0       Male       Baltimore    MD  39.339345
# Bat-000099        26.0       Male     Baton Rouge    LA  30.479034
# Bat-000219        27.0       Male     Baton Rouge    LA  30.419692
# Bat-000329        37.0       Male     Baton Rouge    LA  30.475005
# Bir-000676        24.0       Male      Birmingham    AL  33.562451
# Bos-000131        21.0       Male          Boston    MA  42.328901
# Buf-000283        22.0       Male         Buffalo    NY  42.908799
# Buf-000604        29.0       Male         Buffalo    NY  42.899561
# Cha-000317        21.0       Male       Charlotte    NC  35.196280
# Cha-000403        21.0       Male       Charlotte    NC  35.259581
# Chi-003487        43.0       Male         Chicago    IL  41.855291
# Chi-003521        31.0       Male         Chicago    IL  41.902167
# Chi-003556        21.0       Male         Chicago    IL  41.887702
# Chi-003742        27.0       Male         Chicago    IL  41.961187
# Chi-003931        15.0       Male         Chicago    IL  41.804855
# Chi-003937        35.0       Male         Chicago    IL  41.905775
# Chi-003976        15.0       Male         Chicago    IL  41.838778
# Chi-004165        46.0       Male         Chicago    IL  41.933884
# Chi-004275        30.0       Male         Chicago    IL  41.762879
# Chi-004301        31.0       Male         Chicago    IL  41.834237
# Chi-004337        24.0       Male         Chicago    IL  41.897905
# Chi-004810        35.0       Male         Chicago    IL  41.991391
# Chi-005053        27.0       Male         Chicago    IL  41.826800
# Chi-005079        18.0       Male         Chicago    IL  41.849080
# Chi-005316        16.0       Male         Chicago    IL  41.825219
# Chi-005509        19.0       Male         Chicago    IL  41.902445
# Chi-005581        24.0       Male         Chicago    IL  41.849102
# Chi-006810        25.0       Male         Chicago    IL  41.922708
# ...                ...        ...             ...   ...        ...
# Pho-000721         NaN    Unknown         Phoenix    AZ  33.486800
# SA-000054         25.0       Male     San Antonio    TX  29.478092
# SA-000063         66.0       Male     San Antonio    TX  29.365317
# SA-000074         38.0       Male     San Antonio    TX  29.421180
# SA-000092         26.0       Male     San Antonio    TX  29.329335
# SA-000112         28.0       Male     San Antonio    TX  29.499398
# SA-000151         20.0       Male     San Antonio    TX  29.393726
# SA-000202         73.0       Male     San Antonio    TX  29.460488
# SA-000206         39.0       Male     San Antonio    TX  29.529929
# SA-000328         41.0       Male     San Antonio    TX  29.508530
# SA-000395         30.0       Male     San Antonio    TX  29.411275
# SA-000653         22.0       Male     San Antonio    TX  29.441143
# SA-000712         33.0       Male     San Antonio    TX  29.426962
# SA-000834         29.0       Male     San Antonio    TX  29.568715
# SA-000868         45.0       Male     San Antonio    TX  29.431177
# SA-000943         41.0       Male     San Antonio    TX  29.360745
# SB-000093         50.0       Male  San Bernardino    CA  34.075761
# SD-000429         26.0       Male       San Diego    CA  32.750919
# SF-000066         39.0       Male   San Francisco    CA  37.722381
# SF-000072         43.0       Male   San Francisco    CA  37.780078
# SF-000142         34.0       Male   San Francisco    CA  37.711131
# SF-000257         23.0       Male   San Francisco    CA  37.754335
# StL-001150        25.0       Male       St. Louis    MO  38.664081
# Tam-000113        51.0       Male           Tampa    FL  27.954164
# Tul-000205        26.0       Male           Tulsa    OK  36.230585
# Tul-000247        19.0       Male           Tulsa    OK  36.186102
# Tul-000253         NaN       Male           Tulsa    OK  36.058258
# Tul-000605        34.0       Male           Tulsa    OK  36.096514
# Tul-000741        35.0       Male           Tulsa    OK  36.129921
# Was-000392        45.0       Male      Washington    DC  38.930813
#
#                    lon            disposition  victim_age_numeric       date  \
# uid
# Alb-000001 -106.538555  Closed without arrest                78.0 2010-05-04
# Alb-000315 -106.618029         Open/No arrest                26.0 2017-02-07
# Bal-002139  -76.662483       Closed by arrest                14.0 2009-01-25
# Bat-000099  -91.104891         Open/No arrest                26.0 2012-07-01
# Bat-000219  -91.137286       Closed by arrest                27.0 2014-11-16
# Bat-000329  -91.141693       Closed by arrest                37.0 2016-12-11
# Bir-000676  -86.730470         Open/No arrest                24.0 2008-04-06
# Bos-000131  -71.102496         Open/No arrest                21.0 2014-09-30
# Buf-000283  -78.894391       Closed by arrest                22.0 2009-03-18
# Buf-000604  -78.890157       Closed by arrest                29.0 2015-09-01
# Cha-000317  -80.868290       Closed by arrest                21.0 2008-12-06
# Cha-000403  -80.776519         Open/No arrest                21.0 2010-05-09
# Chi-003487  -87.667389       Closed by arrest                43.0 2007-07-01
# Chi-003521  -87.695693       Closed by arrest                31.0 2007-07-23
# Chi-003556  -87.731538         Open/No arrest                21.0 2007-08-18
# Chi-003742  -87.707017       Closed by arrest                27.0 2008-01-08
# Chi-003931  -87.675816         Open/No arrest                15.0 2008-06-17
# Chi-003937  -87.689814       Closed by arrest                35.0 2008-06-20
# Chi-003976  -87.720744       Closed by arrest                15.0 2008-07-12
# Chi-004165  -87.703809         Open/No arrest                46.0 2008-10-26
# Chi-004275  -87.617206         Open/No arrest                30.0 2009-02-17
# Chi-004301  -87.717174         Open/No arrest                31.0 2009-03-19
# Chi-004337  -87.737253  Closed without arrest                24.0 2009-04-23
# Chi-004810  -87.709105         Open/No arrest                35.0 2010-04-23
# Chi-005053  -87.669088         Open/No arrest                27.0 2010-10-11
# Chi-005079  -87.703055         Open/No arrest                18.0 2010-11-06
# Chi-005316  -87.702380         Open/No arrest                16.0 2011-06-30
# Chi-005509  -87.667782       Closed by arrest                19.0 2011-11-06
# Chi-005581  -87.701484         Open/No arrest                24.0 2012-01-08
# Chi-006810  -87.780540         Open/No arrest                25.0 2014-10-12
# ...                ...                    ...                 ...        ...
# Pho-000721 -112.227201       Closed by arrest                 NaN 2016-09-17
# SA-000054   -98.539601         Open/No arrest                25.0 2008-07-05
# SA-000063   -98.468658  Closed without arrest                66.0 2007-11-17
# SA-000074   -98.556571       Closed by arrest                38.0 2008-09-01
# SA-000092   -98.576555         Open/No arrest                26.0 2008-10-09
# SA-000112   -98.371041       Closed by arrest                28.0 2008-12-04
# SA-000151   -98.433106       Closed by arrest                20.0 2007-04-07
# SA-000202   -98.533830       Closed by arrest                73.0 2007-08-23
# SA-000206   -98.406143       Closed by arrest                39.0 2007-08-30
# SA-000328   -98.387010       Closed by arrest                41.0 2009-10-18
# SA-000395   -98.629187       Closed by arrest                30.0 2010-08-02
# SA-000653   -98.529814       Closed by arrest                22.0 2013-08-26
# SA-000712   -98.572412         Open/No arrest                33.0 2014-05-13
# SA-000834   -98.520201         Open/No arrest                29.0 2015-06-25
# SA-000868   -98.525791       Closed by arrest                45.0 2015-10-18
# SA-000943   -98.633261       Closed by arrest                41.0 2016-06-19
# SB-000093  -117.277986  Closed without arrest                50.0 2015-12-02
# SD-000429  -117.104454       Closed by arrest                26.0 2017-01-07
# SF-000066  -122.402769         Open/No arrest                39.0 2007-08-04
# SF-000072  -122.414100         Open/No arrest                43.0 2007-08-31
# SF-000142  -122.450994       Closed by arrest                34.0 2008-05-31
# SF-000257  -122.410242         Open/No arrest                23.0 2010-04-18
# StL-001150  -90.285547       Closed by arrest                25.0 2009-08-19
# Tam-000113  -82.472310       Closed by arrest                51.0 2014-02-25
# Tul-000205  -95.991016       Closed by arrest                26.0 2007-06-10
# Tul-000247  -95.984547       Closed by arrest                19.0 2008-03-22
# Tul-000253  -95.917059         Open/No arrest                 NaN 2008-05-09
# Tul-000605  -95.896020       Closed by arrest                34.0 2014-02-11
# Tul-000741  -95.850461         Open/No arrest                35.0 2016-05-29
# Was-000392  -77.032506       Closed by arrest                45.0 2012-01-18
#
#               year
# uid
# Alb-000001  2010.0
# Alb-000315  2017.0
# Bal-002139  2009.0
# Bat-000099  2012.0
# Bat-000219  2014.0
# Bat-000329  2016.0
# Bir-000676  2008.0
# Bos-000131  2014.0
# Buf-000283  2009.0
# Buf-000604  2015.0
# Cha-000317  2008.0
# Cha-000403  2010.0
# Chi-003487  2007.0
# Chi-003521  2007.0
# Chi-003556  2007.0
# Chi-003742  2008.0
# Chi-003931  2008.0
# Chi-003937  2008.0
# Chi-003976  2008.0
# Chi-004165  2008.0
# Chi-004275  2009.0
# Chi-004301  2009.0
# Chi-004337  2009.0
# Chi-004810  2010.0
# Chi-005053  2010.0
# Chi-005079  2010.0
# Chi-005316  2011.0
# Chi-005509  2011.0
# Chi-005581  2012.0
# Chi-006810  2014.0
# ...            ...
# Pho-000721  2016.0
# SA-000054   2008.0
# SA-000063   2007.0
# SA-000074   2008.0
# SA-000092   2008.0
# SA-000112   2008.0
# SA-000151   2007.0
# SA-000202   2007.0
# SA-000206   2007.0
# SA-000328   2009.0
# SA-000395   2010.0
# SA-000653   2013.0
# SA-000712   2014.0
# SA-000834   2015.0
# SA-000868   2015.0
# SA-000943   2016.0
# SB-000093   2015.0
# SD-000429   2017.0
# SF-000066   2007.0
# SF-000072   2007.0
# SF-000142   2008.0
# SF-000257   2010.0
# StL-001150  2009.0
# Tam-000113  2014.0
# Tul-000205  2007.0
# Tul-000247  2008.0
# Tul-000253  2008.0
# Tul-000605  2014.0
# Tul-000741  2016.0
# Was-000392  2012.0
#
# [183 rows x 14 columns]

# %% [markdown]
# More commonly, the two statements are combined.

# %%
df[df['victim_first'] == 'JUAN']
# Out:
#             reported_date       victim_last victim_first victim_race  \
# uid
# Alb-000001       20100504            GARCIA         JUAN    Hispanic
# Alb-000315       20170207            ROMERO         JUAN       White
# Bal-002139       20090125           JOHNSON         JUAN       Black
# Bat-000099       20120701             LOPEZ         JUAN    Hispanic
# Bat-000219       20141116            JOSEPH         JUAN       Black
# Bat-000329       20161211        MONTGOMERY         JUAN       Black
# Bir-000676       20080406            CARTER         JUAN       Black
# Bos-000131       20140930             NUNEZ         JUAN    Hispanic
# Buf-000283       20090318          QUINONES         JUAN    Hispanic
# Buf-000604       20150901    ORTIZ-SANTIAGO         JUAN    Hispanic
# Cha-000317       20081206          MARTINEZ         JUAN    Hispanic
# Cha-000403       20100509         CONTRERAS         JUAN    Hispanic
# Chi-003487       20070701            OROZCO         JUAN    Hispanic
# Chi-003521       20070723             REYES         JUAN    Hispanic
# Chi-003556       20070818             RAMOS         JUAN    Hispanic
# Chi-003742       20080108            LEBRON         JUAN    Hispanic
# Chi-003931       20080617         HERNANDEZ         JUAN    Hispanic
# Chi-003937       20080620            TORRES         JUAN    Hispanic
# Chi-003976       20080712          AGUILERA         JUAN    Hispanic
# Chi-004165       20081026             URIBE         JUAN    Hispanic
# Chi-004275       20090217           BONILLA         JUAN    Hispanic
# Chi-004301       20090319            TORRES         JUAN    Hispanic
# Chi-004337       20090423         HERNANDEZ         JUAN    Hispanic
# Chi-004810       20100423            MENDEZ         JUAN    Hispanic
# Chi-005053       20101011          MARTINEZ         JUAN    Hispanic
# Chi-005079       20101106          GONZALEZ         JUAN    Hispanic
# Chi-005316       20110630          BAUTISTA         JUAN    Hispanic
# Chi-005509       20111106           SANCHEZ         JUAN    Hispanic
# Chi-005581       20120108          MELENDEZ         JUAN    Hispanic
# Chi-006810       20141012           MERCADO         JUAN    Hispanic
# ...                   ...               ...          ...         ...
# Pho-000721       20160917   GONZALEZ-GARCIA         JUAN     Unknown
# SA-000054        20080705          CARVAJAL         JUAN    Hispanic
# SA-000063        20071117           CABRERA         JUAN    Hispanic
# SA-000074        20080901          HINOJOSA         JUAN    Hispanic
# SA-000092        20081009         MALDONADO         JUAN    Hispanic
# SA-000112        20081204           ALVAREZ         JUAN    Hispanic
# SA-000151        20070407             PARDO         JUAN       Other
# SA-000202        20070823             ABITU         JUAN       Other
# SA-000206        20070830          SALDIVAR         JUAN       Other
# SA-000328        20091018           SANTANA         JUAN       Other
# SA-000395        20100802             DURAN         JUAN    Hispanic
# SA-000653        20130826            FRAIRE         JUAN    Hispanic
# SA-000712        20140513  SANDOVAL-RAMIREZ         JUAN    Hispanic
# SA-000834        20150625             TREJO         JUAN    Hispanic
# SA-000868        20151018          CASTILLO         JUAN    Hispanic
# SA-000943        20160619             AMARO         JUAN    Hispanic
# SB-000093        20151202          ESPINOZA         JUAN       Other
# SD-000429        20170107             YOUNG         JUAN       Black
# SF-000066        20070804         MALDONADO         JUAN    Hispanic
# SF-000072        20070831           SANCHEZ         JUAN    Hispanic
# SF-000142        20080531         RODRIGUEZ         JUAN    Hispanic
# SF-000257        20100418  MENDEZ-HERNANDEZ         JUAN    Hispanic
# StL-001150       20090819            CANNON         JUAN       Black
# Tam-000113       20140225           ORDONEZ         JUAN    Hispanic
# Tul-000205       20070610             DAVIS         JUAN       Black
# Tul-000247       20080322         RODRIGUEZ         JUAN    Hispanic
# Tul-000253       20080509          CASTILLO         JUAN       White
# Tul-000605       20140211           MENDOZA         JUAN       White
# Tul-000741       20160529       GARCIALICEA         JUAN    Hispanic
# Was-000392       20120118           PAREDES         JUAN    Hispanic
#
#             victim_age victim_sex            city state        lat  \
# uid
# Alb-000001        78.0       Male     Albuquerque    NM  35.095788
# Alb-000315        26.0       Male     Albuquerque    NM  35.080584
# Bal-002139        14.0       Male       Baltimore    MD  39.339345
# Bat-000099        26.0       Male     Baton Rouge    LA  30.479034
# Bat-000219        27.0       Male     Baton Rouge    LA  30.419692
# Bat-000329        37.0       Male     Baton Rouge    LA  30.475005
# Bir-000676        24.0       Male      Birmingham    AL  33.562451
# Bos-000131        21.0       Male          Boston    MA  42.328901
# Buf-000283        22.0       Male         Buffalo    NY  42.908799
# Buf-000604        29.0       Male         Buffalo    NY  42.899561
# Cha-000317        21.0       Male       Charlotte    NC  35.196280
# Cha-000403        21.0       Male       Charlotte    NC  35.259581
# Chi-003487        43.0       Male         Chicago    IL  41.855291
# Chi-003521        31.0       Male         Chicago    IL  41.902167
# Chi-003556        21.0       Male         Chicago    IL  41.887702
# Chi-003742        27.0       Male         Chicago    IL  41.961187
# Chi-003931        15.0       Male         Chicago    IL  41.804855
# Chi-003937        35.0       Male         Chicago    IL  41.905775
# Chi-003976        15.0       Male         Chicago    IL  41.838778
# Chi-004165        46.0       Male         Chicago    IL  41.933884
# Chi-004275        30.0       Male         Chicago    IL  41.762879
# Chi-004301        31.0       Male         Chicago    IL  41.834237
# Chi-004337        24.0       Male         Chicago    IL  41.897905
# Chi-004810        35.0       Male         Chicago    IL  41.991391
# Chi-005053        27.0       Male         Chicago    IL  41.826800
# Chi-005079        18.0       Male         Chicago    IL  41.849080
# Chi-005316        16.0       Male         Chicago    IL  41.825219
# Chi-005509        19.0       Male         Chicago    IL  41.902445
# Chi-005581        24.0       Male         Chicago    IL  41.849102
# Chi-006810        25.0       Male         Chicago    IL  41.922708
# ...                ...        ...             ...   ...        ...
# Pho-000721         NaN    Unknown         Phoenix    AZ  33.486800
# SA-000054         25.0       Male     San Antonio    TX  29.478092
# SA-000063         66.0       Male     San Antonio    TX  29.365317
# SA-000074         38.0       Male     San Antonio    TX  29.421180
# SA-000092         26.0       Male     San Antonio    TX  29.329335
# SA-000112         28.0       Male     San Antonio    TX  29.499398
# SA-000151         20.0       Male     San Antonio    TX  29.393726
# SA-000202         73.0       Male     San Antonio    TX  29.460488
# SA-000206         39.0       Male     San Antonio    TX  29.529929
# SA-000328         41.0       Male     San Antonio    TX  29.508530
# SA-000395         30.0       Male     San Antonio    TX  29.411275
# SA-000653         22.0       Male     San Antonio    TX  29.441143
# SA-000712         33.0       Male     San Antonio    TX  29.426962
# SA-000834         29.0       Male     San Antonio    TX  29.568715
# SA-000868         45.0       Male     San Antonio    TX  29.431177
# SA-000943         41.0       Male     San Antonio    TX  29.360745
# SB-000093         50.0       Male  San Bernardino    CA  34.075761
# SD-000429         26.0       Male       San Diego    CA  32.750919
# SF-000066         39.0       Male   San Francisco    CA  37.722381
# SF-000072         43.0       Male   San Francisco    CA  37.780078
# SF-000142         34.0       Male   San Francisco    CA  37.711131
# SF-000257         23.0       Male   San Francisco    CA  37.754335
# StL-001150        25.0       Male       St. Louis    MO  38.664081
# Tam-000113        51.0       Male           Tampa    FL  27.954164
# Tul-000205        26.0       Male           Tulsa    OK  36.230585
# Tul-000247        19.0       Male           Tulsa    OK  36.186102
# Tul-000253         NaN       Male           Tulsa    OK  36.058258
# Tul-000605        34.0       Male           Tulsa    OK  36.096514
# Tul-000741        35.0       Male           Tulsa    OK  36.129921
# Was-000392        45.0       Male      Washington    DC  38.930813
#
#                    lon            disposition  victim_age_numeric       date  \
# uid
# Alb-000001 -106.538555  Closed without arrest                78.0 2010-05-04
# Alb-000315 -106.618029         Open/No arrest                26.0 2017-02-07
# Bal-002139  -76.662483       Closed by arrest                14.0 2009-01-25
# Bat-000099  -91.104891         Open/No arrest                26.0 2012-07-01
# Bat-000219  -91.137286       Closed by arrest                27.0 2014-11-16
# Bat-000329  -91.141693       Closed by arrest                37.0 2016-12-11
# Bir-000676  -86.730470         Open/No arrest                24.0 2008-04-06
# Bos-000131  -71.102496         Open/No arrest                21.0 2014-09-30
# Buf-000283  -78.894391       Closed by arrest                22.0 2009-03-18
# Buf-000604  -78.890157       Closed by arrest                29.0 2015-09-01
# Cha-000317  -80.868290       Closed by arrest                21.0 2008-12-06
# Cha-000403  -80.776519         Open/No arrest                21.0 2010-05-09
# Chi-003487  -87.667389       Closed by arrest                43.0 2007-07-01
# Chi-003521  -87.695693       Closed by arrest                31.0 2007-07-23
# Chi-003556  -87.731538         Open/No arrest                21.0 2007-08-18
# Chi-003742  -87.707017       Closed by arrest                27.0 2008-01-08
# Chi-003931  -87.675816         Open/No arrest                15.0 2008-06-17
# Chi-003937  -87.689814       Closed by arrest                35.0 2008-06-20
# Chi-003976  -87.720744       Closed by arrest                15.0 2008-07-12
# Chi-004165  -87.703809         Open/No arrest                46.0 2008-10-26
# Chi-004275  -87.617206         Open/No arrest                30.0 2009-02-17
# Chi-004301  -87.717174         Open/No arrest                31.0 2009-03-19
# Chi-004337  -87.737253  Closed without arrest                24.0 2009-04-23
# Chi-004810  -87.709105         Open/No arrest                35.0 2010-04-23
# Chi-005053  -87.669088         Open/No arrest                27.0 2010-10-11
# Chi-005079  -87.703055         Open/No arrest                18.0 2010-11-06
# Chi-005316  -87.702380         Open/No arrest                16.0 2011-06-30
# Chi-005509  -87.667782       Closed by arrest                19.0 2011-11-06
# Chi-005581  -87.701484         Open/No arrest                24.0 2012-01-08
# Chi-006810  -87.780540         Open/No arrest                25.0 2014-10-12
# ...                ...                    ...                 ...        ...
# Pho-000721 -112.227201       Closed by arrest                 NaN 2016-09-17
# SA-000054   -98.539601         Open/No arrest                25.0 2008-07-05
# SA-000063   -98.468658  Closed without arrest                66.0 2007-11-17
# SA-000074   -98.556571       Closed by arrest                38.0 2008-09-01
# SA-000092   -98.576555         Open/No arrest                26.0 2008-10-09
# SA-000112   -98.371041       Closed by arrest                28.0 2008-12-04
# SA-000151   -98.433106       Closed by arrest                20.0 2007-04-07
# SA-000202   -98.533830       Closed by arrest                73.0 2007-08-23
# SA-000206   -98.406143       Closed by arrest                39.0 2007-08-30
# SA-000328   -98.387010       Closed by arrest                41.0 2009-10-18
# SA-000395   -98.629187       Closed by arrest                30.0 2010-08-02
# SA-000653   -98.529814       Closed by arrest                22.0 2013-08-26
# SA-000712   -98.572412         Open/No arrest                33.0 2014-05-13
# SA-000834   -98.520201         Open/No arrest                29.0 2015-06-25
# SA-000868   -98.525791       Closed by arrest                45.0 2015-10-18
# SA-000943   -98.633261       Closed by arrest                41.0 2016-06-19
# SB-000093  -117.277986  Closed without arrest                50.0 2015-12-02
# SD-000429  -117.104454       Closed by arrest                26.0 2017-01-07
# SF-000066  -122.402769         Open/No arrest                39.0 2007-08-04
# SF-000072  -122.414100         Open/No arrest                43.0 2007-08-31
# SF-000142  -122.450994       Closed by arrest                34.0 2008-05-31
# SF-000257  -122.410242         Open/No arrest                23.0 2010-04-18
# StL-001150  -90.285547       Closed by arrest                25.0 2009-08-19
# Tam-000113  -82.472310       Closed by arrest                51.0 2014-02-25
# Tul-000205  -95.991016       Closed by arrest                26.0 2007-06-10
# Tul-000247  -95.984547       Closed by arrest                19.0 2008-03-22
# Tul-000253  -95.917059         Open/No arrest                 NaN 2008-05-09
# Tul-000605  -95.896020       Closed by arrest                34.0 2014-02-11
# Tul-000741  -95.850461         Open/No arrest                35.0 2016-05-29
# Was-000392  -77.032506       Closed by arrest                45.0 2012-01-18
#
#               year
# uid
# Alb-000001  2010.0
# Alb-000315  2017.0
# Bal-002139  2009.0
# Bat-000099  2012.0
# Bat-000219  2014.0
# Bat-000329  2016.0
# Bir-000676  2008.0
# Bos-000131  2014.0
# Buf-000283  2009.0
# Buf-000604  2015.0
# Cha-000317  2008.0
# Cha-000403  2010.0
# Chi-003487  2007.0
# Chi-003521  2007.0
# Chi-003556  2007.0
# Chi-003742  2008.0
# Chi-003931  2008.0
# Chi-003937  2008.0
# Chi-003976  2008.0
# Chi-004165  2008.0
# Chi-004275  2009.0
# Chi-004301  2009.0
# Chi-004337  2009.0
# Chi-004810  2010.0
# Chi-005053  2010.0
# Chi-005079  2010.0
# Chi-005316  2011.0
# Chi-005509  2011.0
# Chi-005581  2012.0
# Chi-006810  2014.0
# ...            ...
# Pho-000721  2016.0
# SA-000054   2008.0
# SA-000063   2007.0
# SA-000074   2008.0
# SA-000092   2008.0
# SA-000112   2008.0
# SA-000151   2007.0
# SA-000202   2007.0
# SA-000206   2007.0
# SA-000328   2009.0
# SA-000395   2010.0
# SA-000653   2013.0
# SA-000712   2014.0
# SA-000834   2015.0
# SA-000868   2015.0
# SA-000943   2016.0
# SB-000093   2015.0
# SD-000429   2017.0
# SF-000066   2007.0
# SF-000072   2007.0
# SF-000142   2008.0
# SF-000257   2010.0
# StL-001150  2009.0
# Tam-000113  2014.0
# Tul-000205  2007.0
# Tul-000247  2008.0
# Tul-000253  2008.0
# Tul-000605  2014.0
# Tul-000741  2016.0
# Was-000392  2012.0
#
# [183 rows x 14 columns]

# %% [markdown]
# With this method of subsetting, pandas doesn't return a new dataframe, but rather is just hiding some of the rows. So if you want to create a new dataframe based on this subset, you need to append `copy()` to the end.

# %%
new_df = df[df['victim_first'] == 'JUAN'].copy()

# %%
new_df.head()
# Out:
#             reported_date victim_last victim_first victim_race  victim_age  \
# uid
# Alb-000001       20100504      GARCIA         JUAN    Hispanic        78.0
# Alb-000315       20170207      ROMERO         JUAN       White        26.0
# Bal-002139       20090125     JOHNSON         JUAN       Black        14.0
# Bat-000099       20120701       LOPEZ         JUAN    Hispanic        26.0
# Bat-000219       20141116      JOSEPH         JUAN       Black        27.0
#
#            victim_sex         city state        lat         lon  \
# uid
# Alb-000001       Male  Albuquerque    NM  35.095788 -106.538555
# Alb-000315       Male  Albuquerque    NM  35.080584 -106.618029
# Bal-002139       Male    Baltimore    MD  39.339345  -76.662483
# Bat-000099       Male  Baton Rouge    LA  30.479034  -91.104891
# Bat-000219       Male  Baton Rouge    LA  30.419692  -91.137286
#
#                       disposition  victim_age_numeric       date    year
# uid
# Alb-000001  Closed without arrest                78.0 2010-05-04  2010.0
# Alb-000315         Open/No arrest                26.0 2017-02-07  2017.0
# Bal-002139       Closed by arrest                14.0 2009-01-25  2009.0
# Bat-000099         Open/No arrest                26.0 2012-07-01  2012.0
# Bat-000219       Closed by arrest                27.0 2014-11-16  2014.0

# %% [markdown]
# As this selection method returns a dataframe, it can be stored. The following creates two dataframes, one with just the 2016 and one with just the 2017 cases.

# %%
df_2017 = df[df['year'] == 2017].copy()
df_2016 = df[df['year'] == 2016].copy()


df_2017['year'].value_counts()
# Out:
# 2017.0    5048
# Name: year, dtype: int64

# %%
df_2016['year'].value_counts()
# Out:
# 2016.0    6290
# Name: year, dtype: int64

# %% [markdown]
# `value_counts` confirms that the correct cases were grabbed.
#
# Alternatively you may want to limit your dataset by column. In this case, you create a list of the columns you want. This list is also placed in brackets after the dataframe name.

# %% [markdown]
# <div class="alert alert-info">
# <h3> Your turn</h3>
# <p> Create a new dataframe with just the female passengers. Check your work.
#
# </div>

# %% [markdown]
# #### More subsets

# %%
columns_to_keep = ['victim_last', 'victim_first', 'victim_race', 'victim_age', 'victim_sex']

# %%
df[columns_to_keep]
# Out:
#                    victim_last victim_first victim_race  victim_age victim_sex
# uid
# Alb-000001              GARCIA         JUAN    Hispanic        78.0       Male
# Alb-000002             MONTOYA      CAMERON    Hispanic        17.0       Male
# Alb-000003         SATTERFIELD      VIVIANA       White        15.0     Female
# Alb-000004            MENDIOLA       CARLOS    Hispanic        32.0       Male
# Alb-000005                MULA       VIVIAN       White        72.0     Female
# Alb-000006                BOOK    GERALDINE       White        91.0     Female
# Alb-000007           MALDONADO        DAVID    Hispanic        52.0       Male
# Alb-000008           MALDONADO       CONNIE    Hispanic        52.0     Female
# Alb-000009        MARTIN-LEYVA      GUSTAVO       White        56.0       Male
# Alb-000010             HERRERA       ISRAEL    Hispanic        43.0       Male
# Alb-000011  BARRIUS-CAMPANIONI       HECTOR    Hispanic        20.0       Male
# Alb-000012               LUJAN        KEVIN       White         NaN       Male
# Alb-000013           COLLAMORE         JOHN    Hispanic        46.0       Male
# Alb-000014            CHIQUITO        CORIN       Other        16.0       Male
# Alb-000015              TORRES       HECTOR    Hispanic        54.0       Male
# Alb-000016                GRAY     STEFANIA       White        43.0     Female
# Alb-000017               LEYVA         JOEL    Hispanic        52.0       Male
# Alb-000018               DAVID        LARRY       White        52.0       Male
# Alb-000019               BRITO    ELIZABETH       White        22.0     Female
# Alb-000020              CHAVEZ     GREG SR.    Hispanic        49.0       Male
# Alb-000021                KING       TEVION       Black        15.0       Male
# Alb-000022              BOYKIN       CEDRIC       Black        25.0       Male
# Alb-000023            BARRAGAN       MIGUEL       White        20.0       Male
# Alb-000024                FORD       LUTHER       Other        47.0       Male
# Alb-000025             WRONSKI        VIOLA       White        88.0     Female
# Alb-000026             ASHFORD    GUADALUPE    Hispanic        27.0     Female
# Alb-000027              TURNER     MICHELLE       White        36.0     Female
# Alb-000028          CUNNINGHAM       SHARON       White        47.0     Female
# Alb-000029              NGUYEN     SELENAVI       Asian         1.0     Female
# Alb-000030              VALDEZ         BILL    Hispanic        58.0       Male
# ...                        ...          ...         ...         ...        ...
# Was-001353              TURNER      GABRIEL       Black        46.0       Male
# Was-001355             MERIEDY       THOMAS       Black        24.0       Male
# Was-001356                COOK          JOE       Black        35.0       Male
# Was-001357            PHILLIPS      SCORPIO       Black        31.0       Male
# Was-001358              HARRIS       ZORUAN       Black        18.0       Male
# Was-001359               PRATT       ANTINA       Black        40.0     Female
# Was-001360              SILVER      ORLANDO       Black        37.0       Male
# Was-001361              REZENE         NOEL       Black        26.0       Male
# Was-001362             DRAYTON       JAVION       Black         3.0       Male
# Was-001363          MCCULLOUGH      ANTOINE       Black        30.0       Male
# Was-001365                BUIE     SAMUELLE       Black        25.0       Male
# Was-001366            JENNINGS      RASSAAN       Black        19.0       Male
# Was-001367               TYLER     MARQUETT       Black        26.0       Male
# Was-001368              GARRIS      RUDOLPH       Black        25.0       Male
# Was-001369            DANSBURY       AUBREY       Black        27.0       Male
# Was-001370               HANEY       JAQUAN       Black        22.0       Male
# Was-001371            HAMILTON         DANA       Black        44.0       Male
# Was-001372              WRIGHT      RASHAWN       Black        25.0       Male
# Was-001373           BLACKWELL      WESTLEY       Black        38.0       Male
# Was-001374              DOWTIN      HERBERT       Black        22.0       Male
# Was-001375              MEDLAY    DEMETRIUS       Black        22.0       Male
# Was-001376            STEPHENS      JUDONNE       Black        25.0       Male
# Was-001377             PEOPLES      DARNELL       Black        35.0       Male
# Was-001378                IVEY         PAUL       Black        37.0       Male
# Was-001379              HARRIS       SHAROD       Black        20.0       Male
# Was-001380            WILLIAMS         EVAN       Black        29.0       Male
# Was-001381               SMITH         DEON       Black        19.0       Male
# Was-001382          WASHINGTON       WILLIE       Black        23.0       Male
# Was-001383              BARNES       MARCUS       Black        24.0       Male
# Was-001384             JACKSON        KEVIN       Black        17.0       Male
#
# [52179 rows x 5 columns]

# %% [markdown]
# As before, you can you use `copy` to create a new dataset.

# %%
victim_df = df[columns_to_keep].copy()

# %%
victim_df.head()
# Out:
#             victim_last victim_first victim_race  victim_age victim_sex
# uid
# Alb-000001       GARCIA         JUAN    Hispanic        78.0       Male
# Alb-000002      MONTOYA      CAMERON    Hispanic        17.0       Male
# Alb-000003  SATTERFIELD      VIVIANA       White        15.0     Female
# Alb-000004     MENDIOLA       CARLOS    Hispanic        32.0       Male
# Alb-000005         MULA       VIVIAN       White        72.0     Female

# %% [markdown]
# As with the row selection, you don't need to store the column names in a list first. By convention, these two steps are combined. However, combining the steps does create an awkward pair of double brackets.

# %%
place_df = df[['city', 'state', 'lat', 'lon']].copy()

# %%
place_df.head()
# Out:
#                    city state        lat         lon
# uid
# Alb-000001  Albuquerque    NM  35.095788 -106.538555
# Alb-000002  Albuquerque    NM  35.056810 -106.715321
# Alb-000003  Albuquerque    NM  35.086092 -106.695568
# Alb-000004  Albuquerque    NM  35.078493 -106.556094
# Alb-000005  Albuquerque    NM  35.130357 -106.580986

# %% [markdown]
# #### Merging
#
# There are several different ways to combine datasets. The most straightforward is to merge two different datasets who share a key in common. To merge `place_df` with  `victim_df`, for example, you can use the datframe `merge` method.

# %%
merged_df = place_df.merge(victim_df, left_index=True, right_index=True)

merged_df.head()
# Out:
#                    city state        lat         lon  victim_last  \
# uid
# Alb-000001  Albuquerque    NM  35.095788 -106.538555       GARCIA
# Alb-000002  Albuquerque    NM  35.056810 -106.715321      MONTOYA
# Alb-000003  Albuquerque    NM  35.086092 -106.695568  SATTERFIELD
# Alb-000004  Albuquerque    NM  35.078493 -106.556094     MENDIOLA
# Alb-000005  Albuquerque    NM  35.130357 -106.580986         MULA
#
#            victim_first victim_race  victim_age victim_sex
# uid
# Alb-000001         JUAN    Hispanic        78.0       Male
# Alb-000002      CAMERON    Hispanic        17.0       Male
# Alb-000003      VIVIANA       White        15.0     Female
# Alb-000004       CARLOS    Hispanic        32.0       Male
# Alb-000005       VIVIAN       White        72.0     Female

# %% [markdown]
# ### Stacking dataframes

# %%
df_2016 = df[df['year'] == 2016]
len(df_2016)
# Out:
# 6290

# %%
recent_df = pd.concat([df_2017, df_2016])

# %%
len(recent_df)
# Out:
# 11338

# %%
pd.concat([victim_df, place_df], axis = 1)
# Out:
#                    victim_last victim_first victim_race  victim_age  \
# uid
# Alb-000001              GARCIA         JUAN    Hispanic        78.0
# Alb-000002             MONTOYA      CAMERON    Hispanic        17.0
# Alb-000003         SATTERFIELD      VIVIANA       White        15.0
# Alb-000004            MENDIOLA       CARLOS    Hispanic        32.0
# Alb-000005                MULA       VIVIAN       White        72.0
# Alb-000006                BOOK    GERALDINE       White        91.0
# Alb-000007           MALDONADO        DAVID    Hispanic        52.0
# Alb-000008           MALDONADO       CONNIE    Hispanic        52.0
# Alb-000009        MARTIN-LEYVA      GUSTAVO       White        56.0
# Alb-000010             HERRERA       ISRAEL    Hispanic        43.0
# Alb-000011  BARRIUS-CAMPANIONI       HECTOR    Hispanic        20.0
# Alb-000012               LUJAN        KEVIN       White         NaN
# Alb-000013           COLLAMORE         JOHN    Hispanic        46.0
# Alb-000014            CHIQUITO        CORIN       Other        16.0
# Alb-000015              TORRES       HECTOR    Hispanic        54.0
# Alb-000016                GRAY     STEFANIA       White        43.0
# Alb-000017               LEYVA         JOEL    Hispanic        52.0
# Alb-000018               DAVID        LARRY       White        52.0
# Alb-000019               BRITO    ELIZABETH       White        22.0
# Alb-000020              CHAVEZ     GREG SR.    Hispanic        49.0
# Alb-000021                KING       TEVION       Black        15.0
# Alb-000022              BOYKIN       CEDRIC       Black        25.0
# Alb-000023            BARRAGAN       MIGUEL       White        20.0
# Alb-000024                FORD       LUTHER       Other        47.0
# Alb-000025             WRONSKI        VIOLA       White        88.0
# Alb-000026             ASHFORD    GUADALUPE    Hispanic        27.0
# Alb-000027              TURNER     MICHELLE       White        36.0
# Alb-000028          CUNNINGHAM       SHARON       White        47.0
# Alb-000029              NGUYEN     SELENAVI       Asian         1.0
# Alb-000030              VALDEZ         BILL    Hispanic        58.0
# ...                        ...          ...         ...         ...
# Was-001353              TURNER      GABRIEL       Black        46.0
# Was-001355             MERIEDY       THOMAS       Black        24.0
# Was-001356                COOK          JOE       Black        35.0
# Was-001357            PHILLIPS      SCORPIO       Black        31.0
# Was-001358              HARRIS       ZORUAN       Black        18.0
# Was-001359               PRATT       ANTINA       Black        40.0
# Was-001360              SILVER      ORLANDO       Black        37.0
# Was-001361              REZENE         NOEL       Black        26.0
# Was-001362             DRAYTON       JAVION       Black         3.0
# Was-001363          MCCULLOUGH      ANTOINE       Black        30.0
# Was-001365                BUIE     SAMUELLE       Black        25.0
# Was-001366            JENNINGS      RASSAAN       Black        19.0
# Was-001367               TYLER     MARQUETT       Black        26.0
# Was-001368              GARRIS      RUDOLPH       Black        25.0
# Was-001369            DANSBURY       AUBREY       Black        27.0
# Was-001370               HANEY       JAQUAN       Black        22.0
# Was-001371            HAMILTON         DANA       Black        44.0
# Was-001372              WRIGHT      RASHAWN       Black        25.0
# Was-001373           BLACKWELL      WESTLEY       Black        38.0
# Was-001374              DOWTIN      HERBERT       Black        22.0
# Was-001375              MEDLAY    DEMETRIUS       Black        22.0
# Was-001376            STEPHENS      JUDONNE       Black        25.0
# Was-001377             PEOPLES      DARNELL       Black        35.0
# Was-001378                IVEY         PAUL       Black        37.0
# Was-001379              HARRIS       SHAROD       Black        20.0
# Was-001380            WILLIAMS         EVAN       Black        29.0
# Was-001381               SMITH         DEON       Black        19.0
# Was-001382          WASHINGTON       WILLIE       Black        23.0
# Was-001383              BARNES       MARCUS       Black        24.0
# Was-001384             JACKSON        KEVIN       Black        17.0
#
#            victim_sex         city state        lat         lon
# uid
# Alb-000001       Male  Albuquerque    NM  35.095788 -106.538555
# Alb-000002       Male  Albuquerque    NM  35.056810 -106.715321
# Alb-000003     Female  Albuquerque    NM  35.086092 -106.695568
# Alb-000004       Male  Albuquerque    NM  35.078493 -106.556094
# Alb-000005     Female  Albuquerque    NM  35.130357 -106.580986
# Alb-000006     Female  Albuquerque    NM  35.151110 -106.537797
# Alb-000007       Male  Albuquerque    NM  35.111785 -106.712614
# Alb-000008     Female  Albuquerque    NM  35.111785 -106.712614
# Alb-000009       Male  Albuquerque    NM  35.075380 -106.553458
# Alb-000010       Male  Albuquerque    NM  35.065930 -106.572288
# Alb-000011       Male  Albuquerque    NM  35.077375 -106.560569
# Alb-000012       Male  Albuquerque    NM  35.077011 -106.564910
# Alb-000013       Male  Albuquerque    NM  35.064076 -106.608281
# Alb-000014       Male  Albuquerque    NM  35.041491 -106.742147
# Alb-000015       Male  Albuquerque    NM  35.070656 -106.615845
# Alb-000016     Female  Albuquerque    NM  35.070656 -106.615845
# Alb-000017       Male  Albuquerque    NM  35.079082 -106.495949
# Alb-000018       Male  Albuquerque    NM        NaN         NaN
# Alb-000019     Female  Albuquerque    NM  35.110404 -106.523668
# Alb-000020       Male  Albuquerque    NM  35.089572 -106.570078
# Alb-000021       Male  Albuquerque    NM  35.095887 -106.638081
# Alb-000022       Male  Albuquerque    NM  35.095887 -106.638081
# Alb-000023       Male  Albuquerque    NM  35.083401 -106.632941
# Alb-000024       Male  Albuquerque    NM  35.102423 -106.567675
# Alb-000025     Female  Albuquerque    NM  35.095956 -106.561135
# Alb-000026     Female  Albuquerque    NM  35.078462 -106.551755
# Alb-000027     Female  Albuquerque    NM  35.053748 -106.531800
# Alb-000028     Female  Albuquerque    NM  35.053748 -106.531800
# Alb-000029     Female  Albuquerque    NM  35.064456 -106.524458
# Alb-000030       Male  Albuquerque    NM  35.061827 -106.749104
# ...               ...          ...   ...        ...         ...
# Was-001353       Male   Washington    DC  38.857628  -76.996482
# Was-001355       Male   Washington    DC  38.862517  -76.990880
# Was-001356       Male   Washington    DC  38.854721  -76.990795
# Was-001357       Male   Washington    DC  38.877003  -76.995627
# Was-001358       Male   Washington    DC  38.877003  -76.995627
# Was-001359     Female   Washington    DC  38.855699  -76.993248
# Was-001360       Male   Washington    DC  38.860054  -76.991825
# Was-001361       Male   Washington    DC  38.849150  -76.971272
# Was-001362       Male   Washington    DC  38.853961  -76.984712
# Was-001363       Male   Washington    DC  38.843740  -76.977839
# Was-001365       Male   Washington    DC  38.851284  -76.981029
# Was-001366       Male   Washington    DC  38.851284  -76.981029
# Was-001367       Male   Washington    DC  38.849967  -76.974421
# Was-001368       Male   Washington    DC  38.827191  -76.998183
# Was-001369       Male   Washington    DC  38.829442  -76.993175
# Was-001370       Male   Washington    DC  38.833943  -76.990742
# Was-001371       Male   Washington    DC  38.828365  -76.994431
# Was-001372       Male   Washington    DC  38.835947  -76.990438
# Was-001373       Male   Washington    DC  38.834756  -76.992662
# Was-001374       Male   Washington    DC  38.833190  -76.994345
# Was-001375       Male   Washington    DC  38.843399  -77.000104
# Was-001376       Male   Washington    DC  38.863322  -76.995309
# Was-001377       Male   Washington    DC  38.845871  -76.998169
# Was-001378       Male   Washington    DC  38.826458  -77.003590
# Was-001379       Male   Washington    DC  38.827266  -77.001572
# Was-001380       Male   Washington    DC  38.828704  -77.002075
# Was-001381       Male   Washington    DC  38.822852  -77.001725
# Was-001382       Male   Washington    DC  38.828025  -77.002511
# Was-001383       Male   Washington    DC  38.820476  -77.008640
# Was-001384       Male   Washington    DC  38.866689  -76.982409
#
# [52179 rows x 9 columns]

# %% [markdown]
# ### New features

# %%
df['birth_year'] = df['year'] - df['victim_age_numeric']

# %%
df['birth_year'].describe()
# Out:
# count    49180.000000
# mean      1980.528223
# std         14.629224
# min       1907.000000
# 25%       1973.000000
# 50%       1984.000000
# 75%       1991.000000
# max       2017.000000
# Name: birth_year, dtype: float64

# %%
df['minor'] = df['victim_age'] <= 18

# %%
df['minor'][:10]
# Out:
# uid
# Alb-000001    False
# Alb-000002     True
# Alb-000003     True
# Alb-000004    False
# Alb-000005    False
# Alb-000006    False
# Alb-000007    False
# Alb-000008    False
# Alb-000009    False
# Alb-000010    False
# Name: minor, dtype: bool

# %%
df['minor'].mean()
# Out:
# 0.10931600835585197

# %% [markdown]
# <div class="alert alert-info">
# <h3> Your turn</h3>
# <p> Create a new variable in your Titanic dataframe which marks the people who paid a fare in the top 25% of all fares paid.
#
# </div>

# %% [markdown]
# ### Back to some pandas string manipulation fun.

# %%
def title_case(text):
    return text.title()

# %%
title_case('JUAN')
# Out:
# 'Juan'

# %% [markdown]
# ### The apply magic

# %%
df['victim_first'].apply(title_case)
# Out:
# uid
# Alb-000001         Juan
# Alb-000002      Cameron
# Alb-000003      Viviana
# Alb-000004       Carlos
# Alb-000005       Vivian
# Alb-000006    Geraldine
# Alb-000007        David
# Alb-000008       Connie
# Alb-000009      Gustavo
# Alb-000010       Israel
# Alb-000011       Hector
# Alb-000012        Kevin
# Alb-000013         John
# Alb-000014        Corin
# Alb-000015       Hector
# Alb-000016     Stefania
# Alb-000017         Joel
# Alb-000018        Larry
# Alb-000019    Elizabeth
# Alb-000020     Greg Sr.
# Alb-000021       Tevion
# Alb-000022       Cedric
# Alb-000023       Miguel
# Alb-000024       Luther
# Alb-000025        Viola
# Alb-000026    Guadalupe
# Alb-000027     Michelle
# Alb-000028       Sharon
# Alb-000029     Selenavi
# Alb-000030         Bill
#                 ...
# Was-001353      Gabriel
# Was-001355       Thomas
# Was-001356          Joe
# Was-001357      Scorpio
# Was-001358       Zoruan
# Was-001359       Antina
# Was-001360      Orlando
# Was-001361         Noel
# Was-001362       Javion
# Was-001363      Antoine
# Was-001365     Samuelle
# Was-001366      Rassaan
# Was-001367     Marquett
# Was-001368      Rudolph
# Was-001369       Aubrey
# Was-001370       Jaquan
# Was-001371         Dana
# Was-001372      Rashawn
# Was-001373      Westley
# Was-001374      Herbert
# Was-001375    Demetrius
# Was-001376      Judonne
# Was-001377      Darnell
# Was-001378         Paul
# Was-001379       Sharod
# Was-001380         Evan
# Was-001381         Deon
# Was-001382       Willie
# Was-001383       Marcus
# Was-001384        Kevin
# Name: victim_first, Length: 52179, dtype: object

# %%
df['victim_first2'] = df['victim_first'].apply(title_case)

# %%
df['victim_first2'].head(10)
# Out:
# uid
# Alb-000001         Juan
# Alb-000002      Cameron
# Alb-000003      Viviana
# Alb-000004       Carlos
# Alb-000005       Vivian
# Alb-000006    Geraldine
# Alb-000007        David
# Alb-000008       Connie
# Alb-000009      Gustavo
# Alb-000010       Israel
# Name: victim_first2, dtype: object

# %%
df[['victim_first', 'victim_first2']].head(10)
# Out:
#            victim_first victim_first2
# uid
# Alb-000001         JUAN          Juan
# Alb-000002      CAMERON       Cameron
# Alb-000003      VIVIANA       Viviana
# Alb-000004       CARLOS        Carlos
# Alb-000005       VIVIAN        Vivian
# Alb-000006    GERALDINE     Geraldine
# Alb-000007        DAVID         David
# Alb-000008       CONNIE        Connie
# Alb-000009      GUSTAVO       Gustavo
# Alb-000010       ISRAEL        Israel

# %% [markdown]
# <div class="alert alert-info">
# <h3> Your turn</h3>
# <p> Write a function that extracts the last name from the name field on your Titanic dataframe.
# Create a new variable called <code>Family Name</code> to store the results. What is the most common family name?
#
# </div>

# %% [markdown]
# Working on more than one column

# %%
def victim_name(row):
    first_name = row['victim_first']
    last_name  = row['victim_last']
    name       = last_name + ', ' + first_name
    name       = title_case(name)
    return name

# %%
df.apply(victim_name, axis=1)
# Out:
# uid
# Alb-000001                  Garcia, Juan
# Alb-000002              Montoya, Cameron
# Alb-000003          Satterfield, Viviana
# Alb-000004              Mendiola, Carlos
# Alb-000005                  Mula, Vivian
# Alb-000006               Book, Geraldine
# Alb-000007              Maldonado, David
# Alb-000008             Maldonado, Connie
# Alb-000009         Martin-Leyva, Gustavo
# Alb-000010               Herrera, Israel
# Alb-000011    Barrius-Campanioni, Hector
# Alb-000012                  Lujan, Kevin
# Alb-000013               Collamore, John
# Alb-000014               Chiquito, Corin
# Alb-000015                Torres, Hector
# Alb-000016                Gray, Stefania
# Alb-000017                   Leyva, Joel
# Alb-000018                  David, Larry
# Alb-000019              Brito, Elizabeth
# Alb-000020              Chavez, Greg Sr.
# Alb-000021                  King, Tevion
# Alb-000022                Boykin, Cedric
# Alb-000023              Barragan, Miguel
# Alb-000024                  Ford, Luther
# Alb-000025                Wronski, Viola
# Alb-000026            Ashford, Guadalupe
# Alb-000027              Turner, Michelle
# Alb-000028            Cunningham, Sharon
# Alb-000029              Nguyen, Selenavi
# Alb-000030                  Valdez, Bill
#                          ...
# Was-001353               Turner, Gabriel
# Was-001355               Meriedy, Thomas
# Was-001356                     Cook, Joe
# Was-001357             Phillips, Scorpio
# Was-001358                Harris, Zoruan
# Was-001359                 Pratt, Antina
# Was-001360               Silver, Orlando
# Was-001361                  Rezene, Noel
# Was-001362               Drayton, Javion
# Was-001363           Mccullough, Antoine
# Was-001365                Buie, Samuelle
# Was-001366             Jennings, Rassaan
# Was-001367               Tyler, Marquett
# Was-001368               Garris, Rudolph
# Was-001369              Dansbury, Aubrey
# Was-001370                 Haney, Jaquan
# Was-001371                Hamilton, Dana
# Was-001372               Wright, Rashawn
# Was-001373            Blackwell, Westley
# Was-001374               Dowtin, Herbert
# Was-001375             Medlay, Demetrius
# Was-001376             Stephens, Judonne
# Was-001377              Peoples, Darnell
# Was-001378                    Ivey, Paul
# Was-001379                Harris, Sharod
# Was-001380                Williams, Evan
# Was-001381                   Smith, Deon
# Was-001382            Washington, Willie
# Was-001383                Barnes, Marcus
# Was-001384                Jackson, Kevin
# Length: 52179, dtype: object

# %%
df['victim_name'] = df.apply(victim_name, axis=1)

# %%
df.head()
# Out:
#             reported_date  victim_last victim_first victim_race  victim_age  \
# uid
# Alb-000001       20100504       GARCIA         JUAN    Hispanic        78.0
# Alb-000002       20100216      MONTOYA      CAMERON    Hispanic        17.0
# Alb-000003       20100601  SATTERFIELD      VIVIANA       White        15.0
# Alb-000004       20100101     MENDIOLA       CARLOS    Hispanic        32.0
# Alb-000005       20100102         MULA       VIVIAN       White        72.0
#
#            victim_sex         city state        lat         lon  \
# uid
# Alb-000001       Male  Albuquerque    NM  35.095788 -106.538555
# Alb-000002       Male  Albuquerque    NM  35.056810 -106.715321
# Alb-000003     Female  Albuquerque    NM  35.086092 -106.695568
# Alb-000004       Male  Albuquerque    NM  35.078493 -106.556094
# Alb-000005     Female  Albuquerque    NM  35.130357 -106.580986
#
#                       disposition  victim_age_numeric       date    year  \
# uid
# Alb-000001  Closed without arrest                78.0 2010-05-04  2010.0
# Alb-000002       Closed by arrest                17.0 2010-02-16  2010.0
# Alb-000003  Closed without arrest                15.0 2010-06-01  2010.0
# Alb-000004       Closed by arrest                32.0 2010-01-01  2010.0
# Alb-000005  Closed without arrest                72.0 2010-01-02  2010.0
#
#             birth_year  minor victim_first2           victim_name
# uid
# Alb-000001      1932.0  False          Juan          Garcia, Juan
# Alb-000002      1993.0   True       Cameron      Montoya, Cameron
# Alb-000003      1995.0   True       Viviana  Satterfield, Viviana
# Alb-000004      1978.0  False        Carlos      Mendiola, Carlos
# Alb-000005      1938.0  False        Vivian          Mula, Vivian
