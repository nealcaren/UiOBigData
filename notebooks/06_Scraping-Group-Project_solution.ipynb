# %% [markdown]
# # Scraping
#
# The website [www.finn.no] offers many things for sale.
#
# 1. Create a function that, when given a page number, returns a list of the URLS of specific motorcycles that are for sale on that page.
#
# ```
# def scrape_cycles(page_number):
#     - get html
#     - parse html
#     - extract a list of urls
#
#     return list_of_urls
# ```

# %%
from requests_html import HTMLSession

def scrape_cycles(page_number):
    url = 'https://www.finn.no/mc/all/search.html?page=' + str(page_number)
    session = HTMLSession()
    r = session.get(url)
    parsed_html = r.html
    
    links = []
    for e in parsed_html.find('.ads__unit__link'):
        link = list(e.absolute_links)[0]
        links.append(link)
    return links
    
scrape_cycles(10)
# Out:
# ['https://www.finn.no/mc/all/ad.html?finnkode=154025365',
#  'https://www.finn.no/mc/all/ad.html?finnkode=154083996',
#  'https://www.finn.no/mc/all/ad.html?finnkode=154073713',
#  'https://www.finn.no/mc/all/ad.html?finnkode=154083066',
#  'https://www.finn.no/mc/all/ad.html?finnkode=128352780',
#  'https://www.finn.no/mc/all/ad.html?finnkode=154082124',
#  'https://www.finn.no/mc/all/ad.html?finnkode=154081268',
#  'https://www.finn.no/mc/all/ad.html?finnkode=148655873',
#  'https://www.finn.no/mc/all/ad.html?finnkode=154082109',
#  'https://www.finn.no/mc/all/ad.html?finnkode=154080637',
#  'https://www.finn.no/mc/all/ad.html?finnkode=154080845',
#  'https://www.finn.no/mc/all/ad.html?finnkode=154078850',
#  'https://www.finn.no/mc/all/ad.html?finnkode=147763955',
#  'https://www.finn.no/mc/all/ad.html?finnkode=154079796',
#  'https://www.finn.no/mc/all/ad.html?finnkode=154077560',
#  'https://www.finn.no/mc/all/ad.html?finnkode=154073112',
#  'https://www.finn.no/mc/all/ad.html?finnkode=154079285',
#  'https://www.finn.no/mc/all/ad.html?finnkode=154074869',
#  'https://www.finn.no/mc/all/ad.html?finnkode=154072472',
#  'https://www.finn.no/mc/all/ad.html?finnkode=154071650',
#  'https://www.finn.no/mc/all/ad.html?finnkode=154059203',
#  'https://www.finn.no/mc/all/ad.html?finnkode=154074005',
#  'https://www.finn.no/mc/all/ad.html?finnkode=145300245',
#  'https://www.finn.no/mc/all/ad.html?finnkode=154059377',
#  'https://www.finn.no/mc/all/ad.html?finnkode=153845742',
#  'https://www.finn.no/mc/all/ad.html?finnkode=154071447',
#  'https://www.finn.no/mc/all/ad.html?finnkode=154065385',
#  'https://www.finn.no/mc/all/ad.html?finnkode=154067918',
#  'https://www.finn.no/mc/all/ad.html?finnkode=154068866',
#  'https://www.finn.no/mc/all/ad.html?finnkode=154066150',
#  'https://www.finn.no/mc/all/ad.html?finnkode=154069592',
#  'https://www.finn.no/mc/all/ad.html?finnkode=154069462',
#  'https://www.finn.no/mc/all/ad.html?finnkode=154069358',
#  'https://www.finn.no/mc/all/ad.html?finnkode=154069172',
#  'https://www.finn.no/mc/all/ad.html?finnkode=154069285',
#  'https://www.finn.no/mc/all/ad.html?finnkode=154064143',
#  'https://www.finn.no/mc/all/ad.html?finnkode=150990755',
#  'https://www.finn.no/mc/all/ad.html?finnkode=154065406',
#  'https://www.finn.no/mc/all/ad.html?finnkode=154067301',
#  'https://www.finn.no/mc/all/ad.html?finnkode=154056737',
#  'https://www.finn.no/mc/all/ad.html?finnkode=154067134',
#  'https://www.finn.no/mc/all/ad.html?finnkode=154066944',
#  'https://www.finn.no/mc/all/ad.html?finnkode=154066649',
#  'https://www.finn.no/mc/all/ad.html?finnkode=150949884',
#  'https://www.finn.no/mc/all/ad.html?finnkode=154066463',
#  'https://www.finn.no/mc/all/ad.html?finnkode=147576100',
#  'https://www.finn.no/mc/all/ad.html?finnkode=154065440',
#  'https://www.finn.no/mc/all/ad.html?finnkode=154062596',
#  'https://www.finn.no/mc/all/ad.html?finnkode=154065620',
#  'https://www.finn.no/mc/all/ad.html?finnkode=154065530',
#  'https://www.finn.no/mc/all/ad.html?finnkode=154061682']

# %% [markdown]
# 2. Below is a section of a listing page refering to just one article. This piece can be used by `requests_html` using the following code:
#
# ```
# from requests_html import HTML
# parsed_html_section = HTML(html=html_section)
# ```
# Create a function that scrapes this section and returns a dictionary with entries for the vehicle description ("Yamaha MT-07 2016"), mileage ("7000 km"), and price ("95000 kr").
#
# ```
# def scrape_listing(parsed_html_section):
#     - extract description
#     - extract mileage
#     - extract price
#
#     info = {'description' : description,
#             'mileage'     : mileage,
#             'price'       : price}
#
#
#     return info
# ```
#
# Hints:
# * ```'dog, river, cat'.split(', ')``` will return ```['dog', 'river', `cat')```
# * ```'kr 95\xa0000'.encode('ascii','ignore')``` will return ```kr 95000```

# %%
html_section = '''
<article class="ads__unit">
                        <div aria-owns="result-item-heading-153469431"></div>

    <div class="ads__unit__img">
        <div class="ads__unit__img__ratio img-format img-format--ratio3by2  img-format--centered">
            <img src="https://images.finncdn.no/dynamic/480w/2019/8/vertical-3/01/1/153/469/431_787813931.jpg" class="img-format__img" alt="" srcset="https://images.finncdn.no/dynamic/960w/2019/8/vertical-3/01/1/153/469/431_787813931.jpg 954w, https://images.finncdn.no/dynamic/640w/2019/8/vertical-3/01/1/153/469/431_787813931.jpg 640w, https://images.finncdn.no/dynamic/480w/2019/8/vertical-3/01/1/153/469/431_787813931.jpg 480w, https://images.finncdn.no/dynamic/320w/2019/8/vertical-3/01/1/153/469/431_787813931.jpg 320w, https://images.finncdn.no/dynamic/240w/2019/8/vertical-3/01/1/153/469/431_787813931.jpg 240w" sizes="(min-width: 768px) 240px, 40vw">
        </div>
    </div>

<div class="ads__unit__content">
    <h2 class="ads__unit__content__title ads__unit__content__title--fav-placeholder" id="result-item-heading-153469431">
        <a id="153469431" href="/mc/all/ad.html?finnkode=153469431" class="ads__unit__link" data-finnkode="153469431" data-listposition="3" data-adtypeterm="mc" data-search-resultitem="">

            Yamaha MT-07 2016, 7&nbsp;000 km, kr 95&nbsp;000,-
        </a>
    </h2>
        <div class="ads__unit__content__status u-position-relative">
                <div data-call-out-box-position="" class="u-position-absolute u-top u-right" style="z-index: 1" data-controller="favoriteHeartReact" data-base-resource-url="https://www.finn.no/favorittliste/podium-resource/favorittlistePodlet/favorite-api" data-ad-id="153469431"><button aria-haspopup="dialog" aria-label="Hjertemerke" aria-pressed="false" class="button button--pill icon icon--heart-neutral" title="Legg til favoritt"></button></div>
        </div>
    <span class="ads__unit__content__details">
                <span>Straumen</span>
    </span>

            <p class="ads__unit__content__keys">
                        <span>2016</span>
                        <span>7&nbsp;000 km</span>
                        <span>95&nbsp;000 kr</span>
            </p>
    <p>
        <span class="u-float-left">
                <span class="ads__unit__content__list truncate">Privat</span>
        </span>
    </p>
</div>


                </article>
                '''

# %%
# Out:
# {'https://example.org/mc/all/ad.html?finnkode=153469431'}

# %%
from requests_html import HTML



def scrape_listing(parsed_html_section):
    year = parsed_html_section.find('h2')[0].text.split(',')[0]
    miles = parsed_html_section.find('h2')[0].text.split(',')[1]
    price = parsed_html_section.find('h2')[0].text.split(',')[2]

        
    info = {'description' : year,
                'mileage'     : miles.replace('\xa0',''),
                'price'       : price.replace('\xa0','')}
    # fix for cases with no mileage listed
    if 'kr ' in miles:
        info['mileage'] = 'Missing'
        info['price'] = miles
    return info

scrape_listing(parsed_html_section)
# Out:
# {'description': 'Yamaha MT-07 2016',
#  'mileage': ' 7000 km',
#  'price': ' kr 95000'}

# %% [markdown]
# 3. Create a function that returns a dataframe of the listing information for all the lisitings on a specific search page. Use the function that you created in 2.
#
# Hint:
# * Each of the elements returned by `.find()` using `requests_html` can also be searched. For example, run the following script on your `parsed_html` page:
# ```for parsed_html_section in parsed_html.find('article'):
#     print('New section')
#     print(parsed_html_section.find('h2'))
#     print('')
#     ```

# %%
def scrape_all_listing(page_number):
    url = 'https://www.finn.no/mc/all/search.html?page=' + str(page_number)
    session = HTMLSession()
    r = session.get(url)
    parsed_html = r.html
    
    listings = []
    
    # iterate over each section
    for parsed_html_section in parsed_html.find('.ads__unit'):
        # Only look at the sectionst that actually have listings
        if len(parsed_html_section.absolute_links) > 0:
            info = scrape_listing(parsed_html_section)
            info['url'] = list(parsed_html_section.absolute_links)[0]
        listings.append(info)
    
            
    return listings
    
scrape_all_listing(3)
# Out:
# [{'description': 'Harley-Davidson 2009',
#   'mileage': ' 59000 km',
#   'price': ' kr 228000',
#   'url': 'https://www.finn.no/mc/all/ad.html?finnkode=149299855'},
#  {'description': 'Honda CX500 1980',
#   'mileage': ' 50700 km',
#   'price': ' kr 25000',
#   'url': 'https://www.finn.no/mc/all/ad.html?finnkode=154339239'},
#  {'description': 'Yamaha SR400 2016',
#   'mileage': ' 5620 km',
#   'price': ' kr 49000',
#   'url': 'https://www.finn.no/mc/all/ad.html?finnkode=154343845'},
#  {'description': 'BMW 90/6 1974',
#   'mileage': 'Missing',
#   'price': ' kr 25\xa0000',
#   'url': 'https://www.finn.no/mc/all/ad.html?finnkode=154342347'},
#  {'description': 'Harley-Davidson Sportster 2003',
#   'mileage': ' 17000 km',
#   'price': ' kr 85000',
#   'url': 'https://www.finn.no/mc/all/ad.html?finnkode=154344379'},
#  {'description': 'Honda 900rr 1998',
#   'mileage': ' 31000 km',
#   'price': ' kr 49000',
#   'url': 'https://www.finn.no/mc/all/ad.html?finnkode=154325859'},
#  {'description': 'Honda 900rr 1998',
#   'mileage': ' 31000 km',
#   'price': ' kr 49000',
#   'url': 'https://www.finn.no/mc/all/ad.html?finnkode=154325859'},
#  {'description': 'Suzuki GSX F 600 1999',
#   'mileage': ' 56444 km',
#   'price': ' kr 35000',
#   'url': 'https://www.finn.no/mc/all/ad.html?finnkode=154343487'},
#  {'description': 'Honda CBF 1000 SA 2006',
#   'mileage': ' 31930 km',
#   'price': ' kr 64000',
#   'url': 'https://www.finn.no/mc/all/ad.html?finnkode=154277827'},
#  {'description': 'KTM 1290 SUPER DUKE R 2018',
#   'mileage': ' 14400 km',
#   'price': ' kr 207000',
#   'url': 'https://www.finn.no/mc/all/ad.html?finnkode=149627782'},
#  {'description': 'Honda Z 125 MONKEY BIKE 2019',
#   'mileage': 'Missing',
#   'price': ' kr 47\xa0777',
#   'url': 'https://www.finn.no/mc/all/ad.html?finnkode=154346421'},
#  {'description': 'Honda CBR 1000 RR 2005',
#   'mileage': ' 58000 km',
#   'price': ' kr 70000',
#   'url': 'https://www.finn.no/mc/all/ad.html?finnkode=154343272'},
#  {'description': 'KTM SX-F 250 2018',
#   'mileage': ' 96 km',
#   'price': ' kr 38000',
#   'url': 'https://www.finn.no/mc/all/ad.html?finnkode=154341811'},
#  {'description': 'Honda Goldwing 1800 2002',
#   'mileage': ' 62700 km',
#   'price': ' kr 118000',
#   'url': 'https://www.finn.no/mc/all/ad.html?finnkode=154342956'},
#  {'description': 'Suzuki GSR 2007',
#   'mileage': ' 24603 km',
#   'price': ' kr 49999',
#   'url': 'https://www.finn.no/mc/all/ad.html?finnkode=154340877'},
#  {'description': 'TGB -Bullet 2012',
#   'mileage': ' 10933 km',
#   'price': ' kr 7000',
#   'url': 'https://www.finn.no/mc/all/ad.html?finnkode=154340265'},
#  {'description': 'TGB -Bullet 2012',
#   'mileage': ' 10933 km',
#   'price': ' kr 7000',
#   'url': 'https://www.finn.no/mc/all/ad.html?finnkode=154340265'},
#  {'description': 'BMW R 1200 GS ADVENTURE 2014',
#   'mileage': ' 55000 km',
#   'price': ' kr 170000',
#   'url': 'https://www.finn.no/mc/all/ad.html?finnkode=154340679'},
#  {'description': 'Kawasaki Kx85 høy 2010',
#   'mileage': 'Missing',
#   'price': ' kr 10\xa0000',
#   'url': 'https://www.finn.no/mc/all/ad.html?finnkode=154340870'},
#  {'description': 'KTM XC-W 125 2019',
#   'mileage': 'Missing',
#   'price': ' kr 54\xa0000',
#   'url': 'https://www.finn.no/mc/all/ad.html?finnkode=154338025'},
#  {'description': 'BMW S 1000 XR 2016',
#   'mileage': ' 23908 km',
#   'price': ' kr 188000',
#   'url': 'https://www.finn.no/mc/all/ad.html?finnkode=154337107'},
#  {'description': 'Vespa Piaggio GTS 300ie Super 300CC White m/Vindskjerm',
#   'mileage': ' Ny service',
#   'price': ' Gode dekk',
#   'url': 'https://www.finn.no/mc/all/ad.html?finnkode=154343251'},
#  {'description': 'Yamaha FZ6-S 2009',
#   'mileage': ' 41213 km',
#   'price': ' kr 49900',
#   'url': 'https://www.finn.no/mc/all/ad.html?finnkode=154340110'},
#  {'description': 'Harley-Davidson ULTRA CLASSIC ELECTRA GLIDE 1999',
#   'mileage': ' 81000 km',
#   'price': ' kr 90000',
#   'url': 'https://www.finn.no/mc/all/ad.html?finnkode=154261620'},
#  {'description': 'Suzuki GSXR-1000 2004',
#   'mileage': ' 56800 km',
#   'price': ' kr 47500',
#   'url': 'https://www.finn.no/mc/all/ad.html?finnkode=154335328'},
#  {'description': 'Honda VFR 800 F VELHOLDT OG VELUTSTYRT 1998',
#   'mileage': ' 71000 km',
#   'price': ' kr 45000',
#   'url': 'https://www.finn.no/mc/all/ad.html?finnkode=154326399'},
#  {'description': 'Honda VFR 800 F VELHOLDT OG VELUTSTYRT 1998',
#   'mileage': ' 71000 km',
#   'price': ' kr 45000',
#   'url': 'https://www.finn.no/mc/all/ad.html?finnkode=154326399'},
#  {'description': 'Honda VFR 1200F 2010',
#   'mileage': ' 34997 km',
#   'price': ' kr 110000',
#   'url': 'https://www.finn.no/mc/all/ad.html?finnkode=154334018'},
#  {'description': 'Honda CRF1000 AdventureSport 2019',
#   'mileage': 'Missing',
#   'price': ' kr 177\xa0000',
#   'url': 'https://www.finn.no/mc/all/ad.html?finnkode=154335904'},
#  {'description': 'Suzuki GSX 1400 2004',
#   'mileage': ' 10000 km',
#   'price': ' kr 120000',
#   'url': 'https://www.finn.no/mc/all/ad.html?finnkode=154034520'},
#  {'description': 'KTM 1290 SUPERDUKE R med riktige farger // Nye dekk august 2019 // 2015',
#   'mileage': ' 17900 km',
#   'price': ' kr 179000',
#   'url': 'https://www.finn.no/mc/all/ad.html?finnkode=154331070'},
#  {'description': 'KTM SX 125 2017',
#   'mileage': 'Missing',
#   'price': ' kr 35\xa0000',
#   'url': 'https://www.finn.no/mc/all/ad.html?finnkode=154331332'},
#  {'description': 'Yamaha DT 125 R 2002',
#   'mileage': ' 44000 km',
#   'price': ' kr 17000',
#   'url': 'https://www.finn.no/mc/all/ad.html?finnkode=154328414'},
#  {'description': 'Kawasaki Z400 CUSTOM 1981',
#   'mileage': 'Missing',
#   'price': ' kr 10\xa0000',
#   'url': 'https://www.finn.no/mc/all/ad.html?finnkode=154330328'},
#  {'description': 'Yamaha Fjr1300 2013',
#   'mileage': ' 41300 km',
#   'price': ' kr 139000',
#   'url': 'https://www.finn.no/mc/all/ad.html?finnkode=154331651'},
#  {'description': 'Honda REVERE 1992',
#   'mileage': ' 48157 km',
#   'price': ' kr 17000',
#   'url': 'https://www.finn.no/mc/all/ad.html?finnkode=154327002'},
#  {'description': 'Honda CB 900 F BolDor 1985',
#   'mileage': ' 60500 km',
#   'price': ' kr 52000',
#   'url': 'https://www.finn.no/mc/all/ad.html?finnkode=154328054'},
#  {'description': 'Triumph AMERICA 800 2006',
#   'mileage': ' 9223 km',
#   'price': ' kr 65000',
#   'url': 'https://www.finn.no/mc/all/ad.html?finnkode=148467540'},
#  {'description': 'Harley-Davidson Wide Glide 1700 2012',
#   'mileage': ' 12709 km',
#   'price': ' kr 189000',
#   'url': 'https://www.finn.no/mc/all/ad.html?finnkode=154331207'},
#  {'description': 'Harley-Davidson Wide Glide 1600 2010',
#   'mileage': ' 16221 km',
#   'price': ' kr 169000',
#   'url': 'https://www.finn.no/mc/all/ad.html?finnkode=154329802'},
#  {'description': 'BMW K 1200 GT 2003',
#   'mileage': ' 26000 km',
#   'price': ' kr 84900',
#   'url': 'https://www.finn.no/mc/all/ad.html?finnkode=154330930'},
#  {'description': 'Suzuki SV 650 kampanje! 2019',
#   'mileage': 'Missing',
#   'price': ' kr 88\xa0990',
#   'url': 'https://www.finn.no/mc/all/ad.html?finnkode=154326824'},
#  {'description': 'KTM 1290 SUPER DUKE R 2017',
#   'mileage': ' 8000 km',
#   'price': ' kr 205000',
#   'url': 'https://www.finn.no/mc/all/ad.html?finnkode=154324751'},
#  {'description': 'Skyteam 2019 2019',
#   'mileage': ' 17 km',
#   'price': ' kr 15000',
#   'url': 'https://www.finn.no/mc/all/ad.html?finnkode=154325995'},
#  {'description': 'Triumph Tiger 100 SS 1958',
#   'mileage': 'Missing',
#   'price': ' kr 39\xa0000',
#   'url': 'https://www.finn.no/mc/all/ad.html?finnkode=127682030'},
#  {'description': 'Harley-Davidson ELECTRA GLIDE FLHTC CLASSIC 1700 2013',
#   'mileage': ' 16931 km',
#   'price': ' kr 239000',
#   'url': 'https://www.finn.no/mc/all/ad.html?finnkode=154328682'},
#  {'description': 'Honda CFR250R 2011',
#   'mileage': 'Missing',
#   'price': ' kr 20\xa0000',
#   'url': 'https://www.finn.no/mc/all/ad.html?finnkode=154323927'},
#  {'description': 'Yamaha YZF R1 2007',
#   'mileage': ' 67000 km',
#   'price': ' kr 70000',
#   'url': 'https://www.finn.no/mc/all/ad.html?finnkode=154321576'},
#  {'description': 'Viarelli Viarelli Vincero* Euro IV 2019',
#   'mileage': 'Missing',
#   'price': ' kr 18\xa0890',
#   'url': 'https://www.finn.no/mc/all/ad.html?finnkode=154327130'},
#  {'description': 'BMW R 850 GS 2000',
#   'mileage': ' 82000 km',
#   'price': ' kr 55000',
#   'url': 'https://www.finn.no/mc/all/ad.html?finnkode=154320654'},
#  {'description': 'KTM SX 125cc 2004',
#   'mileage': 'Missing',
#   'price': ' kr 10\xa0000',
#   'url': 'https://www.finn.no/mc/all/ad.html?finnkode=154321230'},
#  {'description': 'X-PRO FX 70CC 2019',
#   'mileage': 'Missing',
#   'price': ' kr 4\xa0895',
#   'url': 'https://www.finn.no/mc/all/ad.html?finnkode=154325968'},
#  {'description': 'Dirtbike X-PRO FX 150cc 2019',
#   'mileage': 'Missing',
#   'price': ' kr 8\xa0395',
#   'url': 'https://www.finn.no/mc/all/ad.html?finnkode=154325901'},
#  {'description': 'Viarelli Viarelli Rivetto 2019',
#   'mileage': 'Missing',
#   'price': ' kr 16\xa0795',
#   'url': 'https://www.finn.no/mc/all/ad.html?finnkode=154325876'}]

# %%
import pandas as pd

pd.DataFrame(scrape_all_listing(13))
# Out:
#                                           description    mileage        price  \
# 0                          Harley-Davidson FXCWC 2008   49500 km    kr 169900
# 1                             BMW R1250GS *DEMO* 2019    7000 km    kr 259000
# 2                                Honda CBR 125 R 2012   33400 km     kr 14500
# 3                          Vespa VESPA PRIMAVERA 2015    6995 km     kr 22500
# 4                                Yamaha YZF-R125 2008   21300 km     kr 27000
# 5                                  Suzuki VZ 800 2005   11500 km     kr 47500
# 6                                  Suzuki VZ 800 2005   11500 km     kr 47500
# 7                                     BMW F750GS 2019    Missing   kr 166 000
# 8                 Suzuki Burgman AN400ZA Limited 2017   13000 km     kr 74000
# 9                            BMW F800GT KAMPANJE 2019    Missing   kr 155 900
# 10                                  Yamaha MT-07 2016    8000 km     kr 88000
# 11                                Honda CBR 650F 2018    2000 km    kr 105000
# 12                                  Honda Cb650z 1979    Missing    kr 45 000
# 13                            Kawasaki Z1000 ABS 2008   30989 km     kr 95000
# 14                                           BMW 2014   22000 km    kr 229000
# 15                                        Yamaha 1998   47000 km     kr 25000
# 16                                        Yamaha 1998   47000 km     kr 25000
# 17  Honda CB 400F Cafe racer og Suzuki GS 400 1979...    Missing    kr 15 000
# 18                                  Yamaha MT-03 2018    2800 km     kr 60000
# 19                           INDIAN SCOUT BOBBER 2018    7800 km    kr 205000
# 20                                 Yamaha Yz 125 2001    Missing     kr 6 000
# 21                              Yamaha YZF-R125A 2016    9765 km     kr 39500
# 22                                 Suzuki RF 900 1997   57000 km     kr 30000
# 23                                 Yamaha Yz250f 2010      40 km     kr 25000
# 24                                 Yamaha FZR750 1987    Missing    kr 25 000
# 25                     Triumph SPEED TRIPLE 1050 2006   30000 km     kr 68000
# 26                     Triumph SPEED TRIPLE 1050 2006   30000 km     kr 68000
# 27                                   KTM 530 EXC 2010   18000 km     kr 65000
# 28  Harley-Davidson Electra Glide Ultra Classic FL...   20000 km    kr 145000
# 29                                 Honda VTX1800 2007   20498 km     kr 75000
# 30                          Ducati Ducati 750 SS 1998    Missing    kr 34 000
# 31                                Triumph SPRINT 2000   50422 km     kr 38000
# 32                           Honda Cb 750 custom 1982   48382 km     kr 30000
# 33                                   KTM 125 EXC 2013   19970 km     kr 83000
# 34                                     GasGas Ec 2019     924 km     kr 55000
# 35                              Suzuki TS 100 ER 1989    5267 km     kr 36000
# 36                          Gilera RUNNER FX 125 1999   20000 km     kr 16500
# 37                                 Honda CB650FA 2017    2902 km     kr 95000
# 38                                Yamaha 250 yzf 2009    Missing    kr 21 500
# 39                        Suzuki Suzuki GT 125 L 1974   17000 km     kr 25000
# 40                           Honda VT 500 CUSTOM 1986   43431 km     kr 28000
# 41                       INDIAN CHIEF DARK HORSE 2015   10900 km    kr 278000
# 42                                 Honda SH125AD 2013   15400 km     kr 28000
# 43                        Dirtbike X-PRO FX 90CC 2019    Missing     kr 5 095
# 44                   X-Pro Mini dirtbike Firefly 2019    Missing     kr 3 095
# 45            Viarelli Viarelli Monztro Electric 2019    Missing    kr 16 990
# 46                     Viarelli Viarelli Monztro 2019    Missing    kr 19 895
# 47          Harley-Davidson VRSCDX NIGHT ROD SPE 2008   11664 km    kr 164900
# 48                                  Yamaha FZ6-S 2005   13271 km     kr 45000
# 49                               Suzuki GSR 750A 2015    7900 km     kr 98000
# 50                                   Yamaha Mt07 2018    8000 km    kr 100000
# 51                     Viarelli Viarelli Monztro 2019    Missing    kr 19 895
# 52                      MV Agusta TURISMO VELOCE 2015   12978 km    kr 145000
# 53                       Dirtbike X-PRO FX 150cc 2019    Missing     kr 8 395
#
#                                                   url
# 0   https://www.finn.no/mc/all/ad.html?finnkode=14...
# 1   https://www.finn.no/mc/all/ad.html?finnkode=15...
# 2   https://www.finn.no/mc/all/ad.html?finnkode=15...
# 3   https://www.finn.no/mc/all/ad.html?finnkode=15...
# 4   https://www.finn.no/mc/all/ad.html?finnkode=15...
# 5   https://www.finn.no/mc/all/ad.html?finnkode=15...
# 6   https://www.finn.no/mc/all/ad.html?finnkode=15...
# 7   https://www.finn.no/mc/all/ad.html?finnkode=15...
# 8   https://www.finn.no/mc/all/ad.html?finnkode=15...
# 9   https://www.finn.no/mc/all/ad.html?finnkode=15...
# 10  https://www.finn.no/mc/all/ad.html?finnkode=15...
# 11  https://www.finn.no/mc/all/ad.html?finnkode=14...
# 12  https://www.finn.no/mc/all/ad.html?finnkode=15...
# 13  https://www.finn.no/mc/all/ad.html?finnkode=15...
# 14  https://www.finn.no/mc/all/ad.html?finnkode=15...
# 15  https://www.finn.no/mc/all/ad.html?finnkode=12...
# 16  https://www.finn.no/mc/all/ad.html?finnkode=12...
# 17  https://www.finn.no/mc/all/ad.html?finnkode=15...
# 18  https://www.finn.no/mc/all/ad.html?finnkode=15...
# 19  https://www.finn.no/mc/all/ad.html?finnkode=14...
# 20  https://www.finn.no/mc/all/ad.html?finnkode=15...
# 21  https://www.finn.no/mc/all/ad.html?finnkode=15...
# 22  https://www.finn.no/mc/all/ad.html?finnkode=15...
# 23  https://www.finn.no/mc/all/ad.html?finnkode=15...
# 24  https://www.finn.no/mc/all/ad.html?finnkode=14...
# 25  https://www.finn.no/mc/all/ad.html?finnkode=15...
# 26  https://www.finn.no/mc/all/ad.html?finnkode=15...
# 27  https://www.finn.no/mc/all/ad.html?finnkode=15...
# 28  https://www.finn.no/mc/all/ad.html?finnkode=15...
# 29  https://www.finn.no/mc/all/ad.html?finnkode=15...
# 30  https://www.finn.no/mc/all/ad.html?finnkode=15...
# 31  https://www.finn.no/mc/all/ad.html?finnkode=15...
# 32  https://www.finn.no/mc/all/ad.html?finnkode=15...
# 33  https://www.finn.no/mc/all/ad.html?finnkode=15...
# 34  https://www.finn.no/mc/all/ad.html?finnkode=15...
# 35  https://www.finn.no/mc/all/ad.html?finnkode=14...
# 36  https://www.finn.no/mc/all/ad.html?finnkode=15...
# 37  https://www.finn.no/mc/all/ad.html?finnkode=15...
# 38  https://www.finn.no/mc/all/ad.html?finnkode=15...
# 39  https://www.finn.no/mc/all/ad.html?finnkode=15...
# 40  https://www.finn.no/mc/all/ad.html?finnkode=15...
# 41  https://www.finn.no/mc/all/ad.html?finnkode=15...
# 42  https://www.finn.no/mc/all/ad.html?finnkode=15...
# 43  https://www.finn.no/mc/all/ad.html?finnkode=15...
# 44  https://www.finn.no/mc/all/ad.html?finnkode=15...
# 45  https://www.finn.no/mc/all/ad.html?finnkode=15...
# 46  https://www.finn.no/mc/all/ad.html?finnkode=15...
# 47  https://www.finn.no/mc/all/ad.html?finnkode=15...
# 48  https://www.finn.no/mc/all/ad.html?finnkode=15...
# 49  https://www.finn.no/mc/all/ad.html?finnkode=15...
# 50  https://www.finn.no/mc/all/ad.html?finnkode=15...
# 51  https://www.finn.no/mc/all/ad.html?finnkode=15...
# 52  https://www.finn.no/mc/all/ad.html?finnkode=15...
# 53  https://www.finn.no/mc/all/ad.html?finnkode=15...
