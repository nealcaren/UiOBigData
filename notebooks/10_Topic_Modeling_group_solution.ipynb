# %% [markdown]
# ## UN Topic Modeling

# %% [markdown]
# 1. Run all the cells below.
#  * Compare results.
#  * Do the topics make sense?
# 2. Have different members of your group try different vectorizer parameters. What differences do you observe?
# 2. Using the same vectorizer parameters, have different members of your group try different number of topics. What differences do you observe? What is the most sensical number of topics?
# 3. Use a model developed on one sample from the UN to predict document topics for a different sample. Any differences?
# 5. Bonus: Build a pipeline that includes a count vectorizer, topic models, and logistic regression to find the optimal number of topics for predicting speech era.

# %%
# %matplotlib inline

import pandas as pd
# %pip install pdtext --upgrade
# Out:
# Collecting pdtext
#   Downloading https://files.pythonhosted.org/packages/7a/dc/91f5a9ac7fac68257f07322202fcd856d628eca06555efdfef6e1e7662e0/pdtext-0.2.0-py2.py3-none-any.whl
# Installing collected packages: pdtext
#   Found existing installation: pdtext 0.1.2
#     Uninstalling pdtext-0.1.2:
#       Successfully uninstalled pdtext-0.1.2
# Successfully installed pdtext-0.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
un_df = pd.read_json('files/un-general-debates.json')
print(len(un_df))
# Out:
# 7507

# %%
un_df.head()
# Out:
#   country_code                                        speech_text  speech_year
# 0          MDV  ﻿It is indeed a pleasure for me and the member...         1989
# 1          FIN  ﻿\nMay I begin by congratulating you. Sir, on ...         1989
# 2          NER  ﻿\nMr. President, it is a particular pleasure ...         1989
# 3          URY  ﻿\nDuring the debate at the fortieth session o...         1989
# 4          ZWE  ﻿I should like at the outset to express my del...         1989

# %% [markdown]
# The three cells below, which produce the `un_df_sample` dataframe split the speeches into paragraphs and then create a new dataset where each paragraph is a case. The short texts allow for faster, more meaninful analysis. However, 1,386,887 texts is a lot, so only work with a sample of them. I suggest 10,000 cases.

# %%
# split text into paragraphs
un_df['speech_split'] = un_df['speech_text'].str.split('\n')

from pdtext.tools import tokens_to_rows
# create a new dataframe where each paragraph is a row
long_df = tokens_to_rows(un_df['speech_split'])

# merge with original dataset to get year and country
long_df = long_df.set_index('index')
long_df = long_df.merge(un_df[['speech_year', 'country_code']], left_index=True, right_index=True).reset_index()

# eliminate cases where text is blank
filter = long_df["token"] != ""
paragraph_df = long_df[filter].copy().reset_index()

# %%
len(paragraph_df)
# Out:
# 1386887

# %%
un_df_sample = paragraph_df.sample(10000)

# %%
un_df_sample.head(10)
# Out:
#          level_0  index  order  \
# 481440    499061   2769    124
# 530161    548329   3093     42
# 1069186  1103525   5965     18
# 721304    744863   4116     13
# 728499    752253   4138     93
# 184590    193971   1392    100
# 314358    327151   1834     45
# 353721    369624   2140      2
# 611757    633715   3656    153
# 1256686  1295985   6977    121
#
#                                                      token  speech_year  \
# 481440            and defend human rights, our Government          2009
# 530161   184.\tPointing to the example of the European ...         1976
# 1069186  52.\tIn accelerating the arms race, especially...         1981
# 721304   to preside at this session, I should like also...         1982
# 728499   humanity is still very far from having inscrib...         1998
# 184590   objectives contained in these documents. Women...         1996
# 314358   continue to be one of our best hopes for resol...         1997
# 353721   The present session of the United Nations Gene...         1988
# 611757   geography of terrorism envelopes all humanity. We         2005
# 1256686  of the source countries and the destination co...         2006
#
#         country_code
# 481440           TGO
# 530161           IRL
# 1069186          UKR
# 721304           LSO
# 728499           CRI
# 184590           ZMB
# 314358           THA
# 353721           MNG
# 611757           IRQ
# 1256686          WSM

# %%
un_df_sample['post_soviet'] = un_df_sample['speech_year'] > 1991

# %%
# Import the two libraries

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# %%
# set up a vectorizer with 1000 features

vectorizer = CountVectorizer(lowercase    = True,
                             ngram_range  = (1,2),
                             min_df       = .01,
                             stop_words   = 'english',
                             max_df       = .90,
                             max_features = 500)

vectorizer.fit(un_df_sample['token'])
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#                 lowercase=True, max_df=0.9, max_features=500, min_df=0.01,
#                 ngram_range=(1, 2), preprocessor=None, stop_words='english',
#                 strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, vocabulary=None)

# %%
# produce a tf matrix from the vectorizer

un_word_counts = vectorizer.transform(un_df_sample['token'])

# %%
# run th LDA model
lda_model = LatentDirichletAllocation(n_components = 10,
                                      max_iter     = 100,
                                      n_jobs       = -1,
                                      verbose      = 1)

lda_model.fit(un_word_counts)
# Out:
# iteration: 1 of max_iter: 100
# iteration: 2 of max_iter: 100
# iteration: 3 of max_iter: 100
# iteration: 4 of max_iter: 100
# iteration: 5 of max_iter: 100
# iteration: 6 of max_iter: 100
# iteration: 7 of max_iter: 100
# iteration: 8 of max_iter: 100
# iteration: 9 of max_iter: 100
# iteration: 10 of max_iter: 100
# iteration: 11 of max_iter: 100
# iteration: 12 of max_iter: 100
# iteration: 13 of max_iter: 100
# iteration: 14 of max_iter: 100
# iteration: 15 of max_iter: 100
# iteration: 16 of max_iter: 100
# iteration: 17 of max_iter: 100
# iteration: 18 of max_iter: 100
# iteration: 19 of max_iter: 100
# iteration: 20 of max_iter: 100
# iteration: 21 of max_iter: 100
# iteration: 22 of max_iter: 100
# iteration: 23 of max_iter: 100
# iteration: 24 of max_iter: 100
# iteration: 25 of max_iter: 100
# iteration: 26 of max_iter: 100
# iteration: 27 of max_iter: 100
# iteration: 28 of max_iter: 100
# iteration: 29 of max_iter: 100
# iteration: 30 of max_iter: 100
# iteration: 31 of max_iter: 100
# iteration: 32 of max_iter: 100
# iteration: 33 of max_iter: 100
# iteration: 34 of max_iter: 100
# iteration: 35 of max_iter: 100
# iteration: 36 of max_iter: 100
# iteration: 37 of max_iter: 100
# iteration: 38 of max_iter: 100
# iteration: 39 of max_iter: 100
# iteration: 40 of max_iter: 100
# iteration: 41 of max_iter: 100
# iteration: 42 of max_iter: 100
# iteration: 43 of max_iter: 100
# iteration: 44 of max_iter: 100
# iteration: 45 of max_iter: 100
# iteration: 46 of max_iter: 100
# iteration: 47 of max_iter: 100
# iteration: 48 of max_iter: 100
# iteration: 49 of max_iter: 100
# iteration: 50 of max_iter: 100
# iteration: 51 of max_iter: 100
# iteration: 52 of max_iter: 100
# iteration: 53 of max_iter: 100
# iteration: 54 of max_iter: 100
# iteration: 55 of max_iter: 100
# iteration: 56 of max_iter: 100
# iteration: 57 of max_iter: 100
# iteration: 58 of max_iter: 100
# iteration: 59 of max_iter: 100
# iteration: 60 of max_iter: 100
# iteration: 61 of max_iter: 100
# iteration: 62 of max_iter: 100
# iteration: 63 of max_iter: 100
# iteration: 64 of max_iter: 100
# iteration: 65 of max_iter: 100
# iteration: 66 of max_iter: 100
# iteration: 67 of max_iter: 100
# iteration: 68 of max_iter: 100
# iteration: 69 of max_iter: 100
# iteration: 70 of max_iter: 100
# iteration: 71 of max_iter: 100
# iteration: 72 of max_iter: 100
# iteration: 73 of max_iter: 100
# iteration: 74 of max_iter: 100
# iteration: 75 of max_iter: 100
# iteration: 76 of max_iter: 100
# iteration: 77 of max_iter: 100
# iteration: 78 of max_iter: 100
# iteration: 79 of max_iter: 100
# iteration: 80 of max_iter: 100
# iteration: 81 of max_iter: 100
# iteration: 82 of max_iter: 100
# iteration: 83 of max_iter: 100
# iteration: 84 of max_iter: 100
# iteration: 85 of max_iter: 100
# iteration: 86 of max_iter: 100
# iteration: 87 of max_iter: 100
# iteration: 88 of max_iter: 100
# iteration: 89 of max_iter: 100
# iteration: 90 of max_iter: 100
# iteration: 91 of max_iter: 100
# iteration: 92 of max_iter: 100
# iteration: 93 of max_iter: 100
# iteration: 94 of max_iter: 100
# iteration: 95 of max_iter: 100
# iteration: 96 of max_iter: 100
# iteration: 97 of max_iter: 100
# iteration: 98 of max_iter: 100
# iteration: 99 of max_iter: 100
# iteration: 100 of max_iter: 100
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#                           evaluate_every=-1, learning_decay=0.7,
#                           learning_method='batch', learning_offset=10.0,
#                           max_doc_update_iter=100, max_iter=100,
#                           mean_change_tol=0.001, n_components=10, n_jobs=-1,
#                           perp_tol=0.1, random_state=None,
#                           topic_word_prior=None, total_samples=1000000.0,
#                           verbose=1)

# %%
lda_model.components_
# Out:
# array([[1.00022588e-01, 1.00004299e-01, 1.00004164e-01, 1.00006508e-01,
#         3.86390425e+01, 1.00008305e-01, 1.00013143e-01, 1.35976825e+01,
#         1.00009560e-01, 1.00003300e-01, 1.00009067e-01, 1.00012060e-01,
#         1.00019214e-01, 1.00004306e-01, 1.00008504e-01, 1.00009718e-01,
#         1.00006478e-01, 1.00014271e-01, 1.00007824e-01, 1.00014046e-01,
#         1.00010015e-01, 1.00004568e-01, 1.00008881e-01, 1.00010103e-01,
#         1.00006855e-01, 1.00013382e-01, 1.00007232e-01, 1.00010593e-01,
#         1.00017348e-01, 1.00005763e-01, 1.00010438e-01, 1.00009738e-01,
#         1.00021162e-01, 3.16019725e+01, 1.00015273e-01, 8.44099920e+02,
#         1.00015853e-01, 1.00017667e-01, 1.00014463e-01, 1.00003375e-01,
#         1.00009982e-01, 1.00015047e-01, 1.00010648e-01, 3.97775205e+02,
#         1.00019006e-01, 1.00006577e-01, 1.00015995e-01, 1.00008315e-01,
#         1.00012352e-01, 1.00021492e-01, 1.00016300e-01, 1.00015672e-01,
#         1.00017088e-01, 1.00004653e-01, 1.00008541e-01, 1.00015980e-01,
#         1.00010538e-01, 1.00009398e-01, 1.00014663e-01, 1.00007693e-01,
#         1.00020329e-01, 1.00004639e-01, 1.00004356e-01, 1.00008885e-01,
#         1.00002368e-01, 1.00007332e-01, 1.00010071e-01, 1.00007282e-01,
#         1.00017190e-01, 1.00011432e-01, 1.00008765e-01, 1.00010352e-01,
#         1.00007634e-01, 2.59254525e+02, 1.00009327e-01, 1.00006171e-01,
#         1.00010835e-01, 2.79099889e+02, 5.49099910e+02, 1.00022783e-01,
#         1.00019448e-01, 1.00010870e-01, 1.00016006e-01, 1.00005137e-01,
#         1.00008618e-01, 1.07297039e+02, 1.00016826e-01, 3.90893054e+01,
#         1.00015400e-01, 1.00012425e-01, 1.00008629e-01, 1.00010589e-01,
#         1.00007049e-01, 1.00012802e-01, 1.00014778e-01, 1.00007449e-01,
#         1.00015771e-01, 1.00003364e-01, 1.00003238e-01, 1.11759387e+02,
#         1.00001627e-01, 1.00006038e-01, 1.00007884e-01, 1.00008392e-01,
#         1.00005474e-01, 1.00008470e-01, 1.00016265e-01, 1.00008730e-01,
#         1.00009875e-01, 1.00011564e-01, 6.98513232e+01, 1.00006967e-01,
#         1.00006567e-01, 1.00017882e-01, 1.00009771e-01, 1.00003328e-01,
#         1.00019652e-01, 1.00013261e-01, 1.00014938e-01, 1.00017231e-01]])

# %%
from pdtext.tm import topic_words, topic_pred

topic_words(lda_model, vectorizer, ntokens = 20)
# Out:
#                      1           2                 3              4   \
# Topic 1         nations      united    united nations         people
# Topic 2         efforts  government           support        nuclear
# Topic 3           world      states             state           year
# Topic 4   international       order           peoples     conference
# Topic 5     development      africa             south        african
# Topic 6        assembly     general             human        session
# Topic 7        security     council  security council      secretary
# Topic 8       countries    economic         community  international
# Topic 9            time        like             great      relations
# Topic 10          peace     country      organization            new
#
#                  5                 6                  7   \
# Topic 1      states           charter             member
# Topic 2   president           weapons         delegation
# Topic 3    national             today            process
# Topic 4   situation            region               east
# Topic 5        work             years             policy
# Topic 6      rights  general assembly              right
# Topic 7      global           general  secretary general
# Topic 8   political            social         developing
# Topic 9    republic        principles               role
# Topic 10  important              hope           security
#
#                                8         9              10         11  \
# Topic 1                     years  continue         action   problems
# Topic 2                      just    recent       republic        non
# Topic 3                       way   respect            war       make
# Topic 4               cooperation       end         member     states
# Topic 5                  continue    action       problems      trade
# Topic 6                       non   peoples         people  political
# Topic 7                    action       war       continue       make
# Topic 8   international community    future           need  resources
# Topic 9                   charter    states     delegation     people
# Topic 10                 problems     trade  international       just
#
#                      12        13        14            15          16  \
# Topic 1            make      role      year    delegation     peoples
# Topic 2          people    states  continue          make    progress
# Topic 3          recent    action    people       peoples       years
# Topic 4             new       non      make          just      people
# Topic 5            need    recent   peoples          make      states
# Topic 6            work   respect      year        action  delegation
# Topic 7        problems      year      east          role     process
# Topic 8        progress  problems     trade   development      global
# Topic 9   international   respect       new  organization    continue
# Topic 10       progress    people      work       peoples        east
#
#                  17             18       19          20
# Topic 1         new  international     work      recent
# Topic 2      policy          right  country  conference
# Topic 3   political       problems      non    progress
# Topic 4      recent         action      war        year
# Topic 5    national      countries     year      people
# Topic 6   president       progress    years    problems
# Topic 7        need         states  efforts  delegation
# Topic 8        make         recent  peoples         non
# Topic 9       years        peoples     year      policy
# Topic 10        war          years     make  delegation

# %%
un_topics = topic_pred(lda_model, 
                       un_word_counts, 
                       vectorizer)

# %%
un_topics.groupby(un_df_sample['post_soviet']).mean().T
# Out:
# post_soviet                           False     True
# nations_united_united nations      0.122089  0.062500
# efforts_government_support         0.094391  0.062500
# world_states_state                 0.119481  0.062500
# international_order_peoples        0.103398  0.062500
# development_africa_south           0.086565  0.187500
# assembly_general_human             0.083406  0.062500
# security_council_security council  0.091137  0.062500
# countries_economic_community       0.132011  0.062503
# time_like_great                    0.076890  0.062500
# peace_country_organization         0.090630  0.312497

# %%
def make_eras(year):
    if year < 1980:
        return 1975
    elif year < 1990:
        return 1985
    elif year < 2000:
        return 1995
    elif year < 2010:
        return 2005
    return 2015
    
un_df_sample['era'] = un_df_sample['speech_year'].apply(make_eras)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV

# %%
pipeline = Pipeline([
                     ('vectorizer' , CountVectorizer(max_df      = .90,
                                                     stop_words   = 'english',
                                                     )),
                     ('lda' , LatentDirichletAllocation()),
                     ('classifier' , LogisticRegression())
                      ])

parameters = {'lda__n_components' : [10, 20, 40],
              'vectorizer__max_df' : [.5, .8, .9 ], 
              'vectorizer__min_df' : [.01, .02, .05], 
             }

# %%
grid_search = GridSearchCV(pipeline,
                           parameters,
                           n_jobs = -1,
                           cv = 5,
                           verbose = 2)

# %%
grid_search.fit(un_df_sample['token'],
                un_df_sample['era'])
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:   31.2s
# [Parallel(n_jobs=-1)]: Done 135 out of 135 | elapsed:  2.4min finished
# /Users/nealcaren/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/nealcaren/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# GridSearchCV(cv=5, error_score='raise-deprecating',
#              estimator=Pipeline(memory=None,
#                                 steps=[('vectorizer',
#                                         CountVectorizer(analyzer='word',
#                                                         binary=False,
#                                                         decode_error='strict',
#                                                         dtype=<class 'numpy.int64'>,
#                                                         encoding='utf-8',
#                                                         input='content',
#                                                         lowercase=True,
#                                                         max_df=0.9,
#                                                         max_features=None,
#                                                         min_df=1,
#                                                         ngram_range=(1, 1),
#                                                         preprocessor=None,
#                                                         stop_words='english',
#                                                         strip_accen...
#                                                            multi_class='warn',
#                                                            n_jobs=None,
#                                                            penalty='l2',
#                                                            random_state=None,
#                                                            solver='warn',
#                                                            tol=0.0001,
#                                                            verbose=0,
#                                                            warm_start=False))],
#                                 verbose=False),
#              iid='warn', n_jobs=-1,
#              param_grid={'lda__n_components': [10, 20, 40],
#                          'vectorizer__max_df': [0.5, 0.8, 0.9],
#                          'vectorizer__min_df': [0.01, 0.02, 0.05]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=2)

# %%
grid_search.best_estimator_
# Out:
# Pipeline(memory=None,
#          steps=[('vectorizer',
#                  CountVectorizer(analyzer='word', binary=False,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.int64'>, encoding='utf-8',
#                                  input='content', lowercase=True, max_df=0.5,
#                                  max_features=None, min_df=0.02,
#                                  ngram_range=(1, 1), preprocessor=None,
#                                  stop_words='english', strip_accents=None,
#                                  token_pattern='(?u)\\b\\w\\w+\\b',
#                                  tokenizer=None,...
#                                            perp_tol=0.1, random_state=None,
#                                            topic_word_prior=None,
#                                            total_samples=1000000.0,
#                                            verbose=0)),
#                 ('classifier',
#                  LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                     fit_intercept=True, intercept_scaling=1,
#                                     l1_ratio=None, max_iter=100,
#                                     multi_class='warn', n_jobs=None,
#                                     penalty='l2', random_state=None,
#                                     solver='warn', tol=0.0001, verbose=0,
#                                     warm_start=False))],
#          verbose=False)

# %%
grid_search.best_params_
# Out:
# {'lda__n_components': 40,
#  'vectorizer__max_df': 0.5,
#  'vectorizer__min_df': 0.02}
